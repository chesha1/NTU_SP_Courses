# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Collecting huggingface-hub (from timm)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 18.8 MB/s eta 0:00:00
# Collecting safetensors (from timm)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: safetensors, huggingface-hub, timm
# Successfully installed huggingface-hub-0.18.0 safetensors-0.4.0 timm-0.9.7

# %%
import numpy as np
import torch
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from scipy.spatial import distance
from tqdm import tqdm
import timm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 1. 加载 CIFAR-10 数据集
transform = transforms.Compose([
    transforms.Resize((224, 224)), # 调整为预训练模型所需的尺寸
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=False)

test_dataset = CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=False)

# 2. 使用 TIMM 预训练模型进行降维
model = timm.create_model('resnet50', pretrained=True)
model = model.to(device).eval() # 移动模型到GPU并设置为评估模式

# 为了提取倒数第二个全连接层的输出，我们需要删除最后的分类层
model = torch.nn.Sequential(*(list(model.children())[:-1]))

def extract_features(dataloader):
    features = []
    labels = []
    with torch.no_grad():
        for inputs, targets in tqdm(dataloader, desc="Extracting features"):
            inputs = inputs.to(device)
            outputs = model(inputs)
            features.append(outputs.squeeze(-1).squeeze(-1).cpu().numpy())
            labels.append(targets.numpy())
    return np.vstack(features), np.concatenate(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels = extract_features(test_loader)

# 3. 使用最小 Mahalanobis 距离分类器进行分类
class_means = {}
class_cov_matrices = {}
classes = np.unique(train_labels)

for c in classes:
    class_data = train_features[train_labels == c]
    class_means[c] = np.mean(class_data, axis=0)
    class_cov_matrices[c] = np.cov(class_data, rowvar=False)

def mahalanobis_distance(x, mean, cov_matrix):
    return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))

def classify_sample(x):
    distances = {}
    for c in classes:
        distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
    return min(distances, key=distances.get)

train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])

# 计算训练和测试的分类准确率
train_accuracy = np.mean(train_pred == train_labels)
test_accuracy = np.mean(test_pred == test_labels)
print(f"Training accuracy using minimum Mahalanobis distance classifier after feature extraction: {train_accuracy:.4f}")
print(f"Test accuracy using minimum Mahalanobis distance classifier after feature extraction: {test_accuracy:.4f}")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 43557307.67it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Extracting features: 100%|██████████| 391/391 [03:56<00:00,  1.65it/s]
# Extracting features: 100%|██████████| 79/79 [00:47<00:00,  1.66it/s]
# Classifying train samples:   0%|          | 0/50000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-3-6ae19a0107d3> in <cell line: 64>()
#      62     return min(distances, key=distances.get)
#      63
# ---> 64 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      65 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      66
#
# <ipython-input-3-6ae19a0107d3> in <listcomp>(.0)
#      62     return min(distances, key=distances.get)
#      63
# ---> 64 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      65 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      66
#
# <ipython-input-3-6ae19a0107d3> in classify_sample(x)
#      59     distances = {}
#      60     for c in classes:
# ---> 61         distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
#      62     return min(distances, key=distances.get)
#      63
#
# <ipython-input-3-6ae19a0107d3> in mahalanobis_distance(x, mean, cov_matrix)
#      54
#      55 def mahalanobis_distance(x, mean, cov_matrix):
# ---> 56     return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))
#      57
#      58 def classify_sample(x):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     550     signature = 'D->D' if isComplexType(t) else 'd->d'
#     551     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553     return wrap(ainv.astype(result_t, copy=False))
#     554
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      87
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#      90
#      91 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
import numpy as np
import torch
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from scipy.spatial import distance
from tqdm import tqdm
import timm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 1. 加载 CIFAR-10 数据集
transform = transforms.Compose([
    transforms.Resize((224, 224)), # 调整为预训练模型所需的尺寸
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=False)

test_dataset = CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=512, shuffle=False)

# 2. 使用 TIMM 预训练模型进行降维
model = timm.create_model('resnet50', pretrained=True)
model = model.to(device).eval()

# 为了提取倒数第二个全连接层的输出，我们需要删除最后的分类层
model = torch.nn.Sequential(*(list(model.children())[:-1]))

def extract_features(dataloader):
    features = []
    labels = []
    with torch.no_grad():
        for inputs, targets in tqdm(dataloader, desc="Extracting features"):
            inputs = inputs.to(device)
            outputs = model(inputs)
            features.append(outputs.squeeze(-1).squeeze(-1).cpu().numpy())
            labels.append(targets.numpy())
    return np.vstack(features), np.concatenate(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels = extract_features(test_loader)

# 3. 使用最小 Mahalanobis 距离分类器进行分类
class_means = {}
class_cov_matrices = {}
classes = np.unique(train_labels)

regularization_factor = 1e-6
for c in classes:
    class_data = train_features[train_labels == c]
    class_means[c] = np.mean(class_data, axis=0)
    class_cov_matrices[c] = np.cov(class_data, rowvar=False) + np.eye(class_data.shape[1]) * regularization_factor

def mahalanobis_distance(x, mean, cov_matrix):
    return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))

def classify_sample(x):
    distances = {}
    for c in classes:
        distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
    return min(distances, key=distances.get)

train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])

# 计算训练和测试的分类准确率
train_accuracy = np.mean(train_pred == train_labels)
test_accuracy = np.mean(test_pred == test_labels)
print(f"Training accuracy using minimum Mahalanobis distance classifier after feature extraction: {train_accuracy:.4f}")
print(f"Test accuracy using minimum Mahalanobis distance classifier after feature extraction: {test_accuracy:.4f}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Extracting features:   0%|          | 0/98 [00:00<?, ?it/s]
# Extracting features:   1%|          | 1/98 [00:02<03:56,  2.43s/it]
# Extracting features:   2%|▏         | 2/98 [00:04<03:49,  2.39s/it]
# Extracting features:   3%|▎         | 3/98 [00:07<03:45,  2.38s/it]
# Extracting features:   4%|▍         | 4/98 [00:09<03:51,  2.47s/it]
# Extracting features:   5%|▌         | 5/98 [00:12<03:45,  2.42s/it]
# Extracting features:   6%|▌         | 6/98 [00:14<03:40,  2.40s/it]
# Extracting features:   7%|▋         | 7/98 [00:16<03:37,  2.39s/it]
# Extracting features:   8%|▊         | 8/98 [00:19<03:33,  2.37s/it]
# Extracting features:   9%|▉         | 9/98 [00:21<03:32,  2.38s/it]
# Extracting features:  10%|█         | 10/98 [00:24<03:34,  2.43s/it]
# Extracting features:  11%|█         | 11/98 [00:26<03:29,  2.41s/it]
# Extracting features:  12%|█▏        | 12/98 [00:28<03:27,  2.41s/it]
# Extracting features:  13%|█▎        | 13/98 [00:31<03:24,  2.40s/it]
# Extracting features:  14%|█▍        | 14/98 [00:33<03:21,  2.39s/it]
# Extracting features:  15%|█▌        | 15/98 [00:36<03:25,  2.48s/it]
# Extracting features:  16%|█▋        | 16/98 [00:38<03:20,  2.45s/it]
# Extracting features:  17%|█▋        | 17/98 [00:41<03:16,  2.42s/it]
# Extracting features:  18%|█▊        | 18/98 [00:43<03:13,  2.42s/it]
# Extracting features:  19%|█▉        | 19/98 [00:45<03:10,  2.41s/it]
# Extracting features:  20%|██        | 20/98 [00:48<03:14,  2.49s/it]
# Extracting features:  21%|██▏       | 21/98 [00:50<03:09,  2.46s/it]
# Extracting features:  22%|██▏       | 22/98 [00:53<03:05,  2.44s/it]
# Extracting features:  23%|██▎       | 23/98 [00:55<03:02,  2.43s/it]
# Extracting features:  24%|██▍       | 24/98 [00:58<02:59,  2.43s/it]
# Extracting features:  26%|██▌       | 25/98 [01:00<03:04,  2.53s/it]
# Extracting features:  27%|██▋       | 26/98 [01:03<03:00,  2.51s/it]
# Extracting features:  28%|██▊       | 27/98 [01:05<02:56,  2.49s/it]
# Extracting features:  29%|██▊       | 28/98 [01:08<02:53,  2.48s/it]
# Extracting features:  30%|██▉       | 29/98 [01:10<02:50,  2.47s/it]
# Extracting features:  31%|███       | 30/98 [01:13<02:54,  2.56s/it]
# Extracting features:  32%|███▏      | 31/98 [01:15<02:49,  2.53s/it]
# Extracting features:  33%|███▎      | 32/98 [01:18<02:45,  2.50s/it]
# Extracting features:  34%|███▎      | 33/98 [01:20<02:41,  2.49s/it]
# Extracting features:  35%|███▍      | 34/98 [01:23<02:37,  2.47s/it]
# Extracting features:  36%|███▌      | 35/98 [01:26<02:41,  2.56s/it]
# Extracting features:  37%|███▋      | 36/98 [01:28<02:36,  2.52s/it]
# Extracting features:  38%|███▊      | 37/98 [01:30<02:32,  2.50s/it]
# Extracting features:  39%|███▉      | 38/98 [01:33<02:29,  2.49s/it]
# Extracting features:  40%|███▉      | 39/98 [01:35<02:25,  2.47s/it]
# Extracting features:  41%|████      | 40/98 [01:38<02:29,  2.57s/it]
# Extracting features:  42%|████▏     | 41/98 [01:41<02:24,  2.53s/it]
# Extracting features:  43%|████▎     | 42/98 [01:43<02:19,  2.50s/it]
# Extracting features:  44%|████▍     | 43/98 [01:45<02:16,  2.48s/it]
# Extracting features:  45%|████▍     | 44/98 [01:48<02:12,  2.46s/it]
# Extracting features:  46%|████▌     | 45/98 [01:51<02:15,  2.55s/it]
# Extracting features:  47%|████▋     | 46/98 [01:53<02:10,  2.52s/it]
# Extracting features:  48%|████▊     | 47/98 [01:55<02:07,  2.50s/it]
# Extracting features:  49%|████▉     | 48/98 [01:58<02:03,  2.47s/it]
# Extracting features:  50%|█████     | 49/98 [02:00<02:01,  2.47s/it]
# Extracting features:  51%|█████     | 50/98 [02:03<02:03,  2.57s/it]
# Extracting features:  52%|█████▏    | 51/98 [02:06<01:58,  2.53s/it]
# Extracting features:  53%|█████▎    | 52/98 [02:08<01:54,  2.50s/it]
# Extracting features:  54%|█████▍    | 53/98 [02:10<01:51,  2.48s/it]
# Extracting features:  55%|█████▌    | 54/98 [02:13<01:48,  2.46s/it]
# Extracting features:  56%|█████▌    | 55/98 [02:16<01:49,  2.55s/it]
# Extracting features:  57%|█████▋    | 56/98 [02:18<01:45,  2.52s/it]
# Extracting features:  58%|█████▊    | 57/98 [02:20<01:42,  2.50s/it]
# Extracting features:  59%|█████▉    | 58/98 [02:23<01:38,  2.47s/it]
# Extracting features:  60%|██████    | 59/98 [02:25<01:36,  2.47s/it]
# Extracting features:  61%|██████    | 60/98 [02:28<01:37,  2.56s/it]
# Extracting features:  62%|██████▏   | 61/98 [02:31<01:33,  2.52s/it]
# Extracting features:  63%|██████▎   | 62/98 [02:33<01:30,  2.51s/it]
# Extracting features:  64%|██████▍   | 63/98 [02:36<01:27,  2.49s/it]
# Extracting features:  65%|██████▌   | 64/98 [02:38<01:24,  2.48s/it]
# Extracting features:  66%|██████▋   | 65/98 [02:41<01:24,  2.57s/it]
# Extracting features:  67%|██████▋   | 66/98 [02:43<01:20,  2.53s/it]
# Extracting features:  68%|██████▊   | 67/98 [02:46<01:17,  2.50s/it]
# Extracting features:  69%|██████▉   | 68/98 [02:48<01:14,  2.48s/it]
# Extracting features:  70%|███████   | 69/98 [02:50<01:11,  2.47s/it]
# Extracting features:  71%|███████▏  | 70/98 [02:53<01:11,  2.56s/it]
# Extracting features:  72%|███████▏  | 71/98 [02:56<01:08,  2.53s/it]
# Extracting features:  73%|███████▎  | 72/98 [02:58<01:04,  2.50s/it]
# Extracting features:  74%|███████▍  | 73/98 [03:01<01:02,  2.48s/it]
# Extracting features:  76%|███████▌  | 74/98 [03:03<00:59,  2.49s/it]
# Extracting features:  77%|███████▋  | 75/98 [03:06<00:59,  2.57s/it]
# Extracting features:  78%|███████▊  | 76/98 [03:08<00:55,  2.52s/it]
# Extracting features:  79%|███████▊  | 77/98 [03:11<00:52,  2.50s/it]
# Extracting features:  80%|███████▉  | 78/98 [03:13<00:50,  2.52s/it]
# Extracting features:  81%|████████  | 79/98 [03:16<00:47,  2.49s/it]
# Extracting features:  82%|████████▏ | 80/98 [03:19<00:47,  2.62s/it]
# Extracting features:  83%|████████▎ | 81/98 [03:21<00:44,  2.61s/it]
# Extracting features:  84%|████████▎ | 82/98 [03:24<00:40,  2.56s/it]
# Extracting features:  85%|████████▍ | 83/98 [03:26<00:37,  2.52s/it]
# Extracting features:  86%|████████▌ | 84/98 [03:29<00:35,  2.50s/it]
# Extracting features:  87%|████████▋ | 85/98 [03:31<00:33,  2.57s/it]
# Extracting features:  88%|████████▊ | 86/98 [03:34<00:30,  2.53s/it]
# Extracting features:  89%|████████▉ | 87/98 [03:36<00:27,  2.50s/it]
# Extracting features:  90%|████████▉ | 88/98 [03:39<00:24,  2.48s/it]
# Extracting features:  91%|█████████ | 89/98 [03:41<00:22,  2.47s/it]
# Extracting features:  92%|█████████▏| 90/98 [03:44<00:20,  2.55s/it]
# Extracting features:  93%|█████████▎| 91/98 [03:46<00:17,  2.52s/it]
# Extracting features:  94%|█████████▍| 92/98 [03:49<00:14,  2.49s/it]
# Extracting features:  95%|█████████▍| 93/98 [03:51<00:12,  2.48s/it]
# Extracting features:  96%|█████████▌| 94/98 [03:53<00:09,  2.46s/it]
# Extracting features:  97%|█████████▋| 95/98 [03:56<00:07,  2.55s/it]
# Extracting features:  98%|█████████▊| 96/98 [03:59<00:05,  2.52s/it]
# Extracting features:  99%|█████████▉| 97/98 [04:01<00:02,  2.50s/it]
# Extracting features: 100%|██████████| 98/98 [04:03<00:00,  2.48s/it]
#
# Extracting features:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting features:   5%|▌         | 1/20 [00:02<00:46,  2.44s/it]
# Extracting features:  10%|█         | 2/20 [00:05<00:46,  2.60s/it]
# Extracting features:  15%|█▌        | 3/20 [00:07<00:42,  2.53s/it]
# Extracting features:  20%|██        | 4/20 [00:10<00:39,  2.49s/it]
# Extracting features:  25%|██▌       | 5/20 [00:12<00:37,  2.48s/it]
# Extracting features:  30%|███       | 6/20 [00:14<00:34,  2.46s/it]
# Extracting features:  35%|███▌      | 7/20 [00:17<00:33,  2.54s/it]
# Extracting features:  40%|████      | 8/20 [00:20<00:30,  2.50s/it]
# Extracting features:  45%|████▌     | 9/20 [00:22<00:27,  2.48s/it]
# Extracting features:  50%|█████     | 10/20 [00:24<00:24,  2.46s/it]
# Extracting features:  55%|█████▌    | 11/20 [00:27<00:22,  2.45s/it]
# Extracting features:  60%|██████    | 12/20 [00:30<00:20,  2.53s/it]
# Extracting features:  65%|██████▌   | 13/20 [00:32<00:17,  2.49s/it]
# Extracting features:  70%|███████   | 14/20 [00:34<00:14,  2.47s/it]
# Extracting features:  75%|███████▌  | 15/20 [00:37<00:12,  2.46s/it]
# Extracting features:  80%|████████  | 16/20 [00:39<00:09,  2.45s/it]
# Extracting features:  85%|████████▌ | 17/20 [00:42<00:07,  2.52s/it]
# Extracting features:  90%|█████████ | 18/20 [00:44<00:04,  2.49s/it]
# Extracting features:  95%|█████████▌| 19/20 [00:47<00:02,  2.47s/it]
# Extracting features: 100%|██████████| 20/20 [00:48<00:00,  2.43s/it]
#
# Classifying train samples:   0%|          | 0/50000 [00:00<?, ?it/s]
# Classifying train samples:   0%|          | 1/50000 [00:07<99:17:31,  7.15s/it]
# Classifying train samples:   0%|          | 2/50000 [00:15<108:28:10,  7.81s/it]
# Classifying train samples:   0%|          | 3/50000 [00:22<102:32:23,  7.38s/it]
# Classifying train samples:   0%|          | 4/50000 [00:30<107:23:36,  7.73s/it]
# Classifying train samples:   0%|          | 5/50000 [00:38<106:53:54,  7.70s/it]
# Classifying train samples:   0%|          | 6/50000 [00:46<107:40:15,  7.75s/it]
# Classifying train samples:   0%|          | 7/50000 [00:54<110:12:21,  7.94s/it]
# Classifying train samples:   0%|          | 8/50000 [01:01<105:20:56,  7.59s/it]
# Classifying train samples:   0%|          | 9/50000 [01:09<108:42:41,  7.83s/it]
# Classifying train samples:   0%|          | 10/50000 [01:16<104:24:41,  7.52s/it]
# Classifying train samples:   0%|          | 11/50000 [01:24<107:11:39,  7.72s/it]
# Classifying train samples:   0%|          | 12/50000 [01:32<107:43:36,  7.76s/it]
# Classifying train samples:   0%|          | 13/50000 [01:39<106:49:15,  7.69s/it]
# Classifying train samples:   0%|          | 14/50000 [01:48<109:59:32,  7.92s/it]
# Classifying train samples:   0%|          | 15/50000 [01:55<106:00:54,  7.64s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-764341d544c1> in <cell line: 65>()
#      63     return min(distances, key=distances.get)
#      64
# ---> 65 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      66 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      67
#
# <ipython-input-4-764341d544c1> in <listcomp>(.0)
#      63     return min(distances, key=distances.get)
#      64
# ---> 65 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      66 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      67
#
# <ipython-input-4-764341d544c1> in classify_sample(x)
#      60     distances = {}
#      61     for c in classes:
# ---> 62         distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
#      63     return min(distances, key=distances.get)
#      64
#
# <ipython-input-4-764341d544c1> in mahalanobis_distance(x, mean, cov_matrix)
#      55
#      56 def mahalanobis_distance(x, mean, cov_matrix):
# ---> 57     return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))
#      58
#      59 def classify_sample(x):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     550     signature = 'D->D' if isComplexType(t) else 'd->d'
#     551     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553     return wrap(ainv.astype(result_t, copy=False))
#     554
#
# KeyboardInterrupt:

# %%
import numpy as np
import torch
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from scipy.spatial import distance
from tqdm import tqdm
import timm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 1. 加载 CIFAR-10 数据集
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 调整为预训练模型所需的尺寸
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=False)

test_dataset = CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=512, shuffle=False)

# 2. 使用 TIMM 预训练模型进行降维
desired_dim = 512  # 设置你想要的维度

# 定义一个新的线性层进行降维
dim_reduction_layer = torch.nn.Linear(2048, desired_dim).to(device)

# 将其与原始模型连接在一起
model = torch.nn.Sequential(
    *(list(timm.create_model('resnet50', pretrained=True).children())[:-1]),  # 原始的resnet50，但去除最后的分类层
    torch.nn.Flatten(1),  # 压扁张量，使其变为2D
    dim_reduction_layer  # 进行降维
).to(device).eval()

def extract_features(dataloader):
    features = []
    labels = []
    with torch.no_grad():
        for inputs, targets in tqdm(dataloader, desc="Extracting features"):
            inputs = inputs.to(device)
            outputs = model(inputs)
            features.append(outputs.cpu().numpy())
            labels.append(targets.numpy())
    return np.vstack(features), np.concatenate(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels = extract_features(test_loader)

# 3. 使用最小 Mahalanobis 距离分类器进行分类
class_means = {}
class_cov_matrices = {}
classes = np.unique(train_labels)

regularization_factor = 1e-6
for c in classes:
    class_data = train_features[train_labels == c]
    class_means[c] = np.mean(class_data, axis=0)
    class_cov_matrices[c] = np.cov(class_data, rowvar=False) + np.eye(class_data.shape[1]) * regularization_factor

def mahalanobis_distance(x, mean, cov_matrix):
    return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))

def classify_sample(x):
    distances = {}
    for c in classes:
        distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
    return min(distances, key=distances.get)

train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])

# 计算训练和测试的分类准确率
train_accuracy = np.mean(train_pred == train_labels)
test_accuracy = np.mean(test_pred == test_labels)
print(f"Training accuracy using minimum Mahalanobis distance classifier after feature extraction: {train_accuracy:.4f}")
print(f"Test accuracy using minimum Mahalanobobis distance classifier after feature extraction: {test_accuracy:.4f}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Extracting features:   0%|          | 0/98 [00:00<?, ?it/s]
#
# Extracting features:   1%|          | 1/98 [00:02<03:48,  2.36s/it]
#
# Extracting features:   2%|▏         | 2/98 [00:04<03:42,  2.32s/it]
#
# Extracting features:   3%|▎         | 3/98 [00:06<03:39,  2.31s/it]
#
# Extracting features:   4%|▍         | 4/98 [00:09<03:35,  2.29s/it]
#
# Extracting features:   5%|▌         | 5/98 [00:11<03:33,  2.29s/it]
#
# Extracting features:   6%|▌         | 6/98 [00:14<03:41,  2.41s/it]
#
# Extracting features:   7%|▋         | 7/98 [00:16<03:35,  2.37s/it]
#
# Extracting features:   8%|▊         | 8/98 [00:18<03:30,  2.34s/it]
#
# Extracting features:   9%|▉         | 9/98 [00:21<03:27,  2.33s/it]
#
# Extracting features:  10%|█         | 10/98 [00:23<03:24,  2.32s/it]
#
# Extracting features:  11%|█         | 11/98 [00:25<03:29,  2.41s/it]
#
# Extracting features:  12%|█▏        | 12/98 [00:28<03:24,  2.37s/it]
#
# Extracting features:  13%|█▎        | 13/98 [00:30<03:19,  2.35s/it]
#
# Extracting features:  14%|█▍        | 14/98 [00:32<03:16,  2.34s/it]
#
# Extracting features:  15%|█▌        | 15/98 [00:35<03:12,  2.32s/it]
#
# Extracting features:  16%|█▋        | 16/98 [00:37<03:16,  2.40s/it]
#
# Extracting features:  17%|█▋        | 17/98 [00:40<03:12,  2.38s/it]
#
# Extracting features:  18%|█▊        | 18/98 [00:42<03:08,  2.36s/it]
#
# Extracting features:  19%|█▉        | 19/98 [00:44<03:05,  2.35s/it]
#
# Extracting features:  20%|██        | 20/98 [00:46<03:02,  2.34s/it]
#
# Extracting features:  21%|██▏       | 21/98 [00:49<03:00,  2.34s/it]
#
# Extracting features:  22%|██▏       | 22/98 [00:51<03:05,  2.44s/it]
#
# Extracting features:  23%|██▎       | 23/98 [00:54<03:00,  2.41s/it]
#
# Extracting features:  24%|██▍       | 24/98 [00:56<02:56,  2.38s/it]
#
# Extracting features:  26%|██▌       | 25/98 [00:58<02:52,  2.37s/it]
#
# Extracting features:  27%|██▋       | 26/98 [01:01<02:49,  2.36s/it]
#
# Extracting features:  28%|██▊       | 27/98 [01:03<02:53,  2.45s/it]
#
# Extracting features:  29%|██▊       | 28/98 [01:06<02:48,  2.41s/it]
#
# Extracting features:  30%|██▉       | 29/98 [01:08<02:44,  2.38s/it]
#
# Extracting features:  31%|███       | 30/98 [01:10<02:41,  2.37s/it]
#
# Extracting features:  32%|███▏      | 31/98 [01:13<02:37,  2.35s/it]
#
# Extracting features:  33%|███▎      | 32/98 [01:15<02:41,  2.44s/it]
#
# Extracting features:  34%|███▎      | 33/98 [01:18<02:37,  2.42s/it]
#
# Extracting features:  35%|███▍      | 34/98 [01:20<02:33,  2.40s/it]
#
# Extracting features:  36%|███▌      | 35/98 [01:23<02:30,  2.40s/it]
#
# Extracting features:  37%|███▋      | 36/98 [01:25<02:27,  2.38s/it]
#
# Extracting features:  38%|███▊      | 37/98 [01:28<02:30,  2.47s/it]
#
# Extracting features:  39%|███▉      | 38/98 [01:30<02:26,  2.44s/it]
#
# Extracting features:  40%|███▉      | 39/98 [01:32<02:22,  2.41s/it]
#
# Extracting features:  41%|████      | 40/98 [01:35<02:19,  2.40s/it]
#
# Extracting features:  42%|████▏     | 41/98 [01:37<02:15,  2.38s/it]
#
# Extracting features:  43%|████▎     | 42/98 [01:40<02:16,  2.44s/it]
#
# Extracting features:  44%|████▍     | 43/98 [01:42<02:13,  2.42s/it]
#
# Extracting features:  45%|████▍     | 44/98 [01:44<02:09,  2.40s/it]
#
# Extracting features:  46%|████▌     | 45/98 [01:47<02:06,  2.39s/it]
#
# Extracting features:  47%|████▋     | 46/98 [01:49<02:03,  2.38s/it]
#
# Extracting features:  48%|████▊     | 47/98 [01:52<02:03,  2.42s/it]
#
# Extracting features:  49%|████▉     | 48/98 [01:54<02:03,  2.46s/it]
#
# Extracting features:  50%|█████     | 49/98 [01:56<01:59,  2.44s/it]
#
# Extracting features:  51%|█████     | 50/98 [01:59<01:56,  2.42s/it]
#
# Extracting features:  52%|█████▏    | 51/98 [02:01<01:53,  2.41s/it]
#
# Extracting features:  53%|█████▎    | 52/98 [02:04<01:50,  2.41s/it]
#
# Extracting features:  54%|█████▍    | 53/98 [02:06<01:52,  2.50s/it]
#
# Extracting features:  55%|█████▌    | 54/98 [02:09<01:48,  2.46s/it]
#
# Extracting features:  56%|█████▌    | 55/98 [02:11<01:44,  2.44s/it]
#
# Extracting features:  57%|█████▋    | 56/98 [02:14<01:42,  2.43s/it]
#
# Extracting features:  58%|█████▊    | 57/98 [02:16<01:39,  2.42s/it]
#
# Extracting features:  59%|█████▉    | 58/98 [02:19<01:40,  2.51s/it]
#
# Extracting features:  60%|██████    | 59/98 [02:21<01:36,  2.48s/it]
#
# Extracting features:  61%|██████    | 60/98 [02:23<01:33,  2.46s/it]
#
# Extracting features:  62%|██████▏   | 61/98 [02:26<01:30,  2.44s/it]
#
# Extracting features:  63%|██████▎   | 62/98 [02:28<01:27,  2.43s/it]
#
# Extracting features:  64%|██████▍   | 63/98 [02:31<01:28,  2.53s/it]
#
# Extracting features:  65%|██████▌   | 64/98 [02:33<01:24,  2.50s/it]
#
# Extracting features:  66%|██████▋   | 65/98 [02:36<01:21,  2.48s/it]
#
# Extracting features:  67%|██████▋   | 66/98 [02:38<01:18,  2.47s/it]
#
# Extracting features:  68%|██████▊   | 67/98 [02:41<01:16,  2.46s/it]
#
# Extracting features:  69%|██████▉   | 68/98 [02:44<01:16,  2.56s/it]
#
# Extracting features:  70%|███████   | 69/98 [02:46<01:13,  2.52s/it]
#
# Extracting features:  71%|███████▏  | 70/98 [02:48<01:10,  2.50s/it]
#
# Extracting features:  72%|███████▏  | 71/98 [02:51<01:07,  2.48s/it]
#
# Extracting features:  73%|███████▎  | 72/98 [02:53<01:04,  2.47s/it]
#
# Extracting features:  74%|███████▍  | 73/98 [02:56<01:04,  2.56s/it]
#
# Extracting features:  76%|███████▌  | 74/98 [02:59<01:00,  2.53s/it]
#
# Extracting features:  77%|███████▋  | 75/98 [03:01<00:57,  2.50s/it]
#
# Extracting features:  78%|███████▊  | 76/98 [03:03<00:54,  2.49s/it]
#
# Extracting features:  79%|███████▊  | 77/98 [03:06<00:52,  2.48s/it]
#
# Extracting features:  80%|███████▉  | 78/98 [03:09<00:51,  2.57s/it]
#
# Extracting features:  81%|████████  | 79/98 [03:11<00:48,  2.54s/it]
#
# Extracting features:  82%|████████▏ | 80/98 [03:14<00:45,  2.50s/it]
#
# Extracting features:  83%|████████▎ | 81/98 [03:16<00:42,  2.49s/it]
#
# Extracting features:  84%|████████▎ | 82/98 [03:18<00:39,  2.47s/it]
#
# Extracting features:  85%|████████▍ | 83/98 [03:21<00:38,  2.57s/it]
#
# Extracting features:  86%|████████▌ | 84/98 [03:24<00:35,  2.52s/it]
#
# Extracting features:  87%|████████▋ | 85/98 [03:26<00:32,  2.49s/it]
#
# Extracting features:  88%|████████▊ | 86/98 [03:29<00:29,  2.48s/it]
#
# Extracting features:  89%|████████▉ | 87/98 [03:31<00:27,  2.46s/it]
#
# Extracting features:  90%|████████▉ | 88/98 [03:34<00:25,  2.55s/it]
#
# Extracting features:  91%|█████████ | 89/98 [03:36<00:22,  2.52s/it]
#
# Extracting features:  92%|█████████▏| 90/98 [03:39<00:19,  2.50s/it]
#
# Extracting features:  93%|█████████▎| 91/98 [03:41<00:17,  2.48s/it]
#
# Extracting features:  94%|█████████▍| 92/98 [03:43<00:14,  2.47s/it]
#
# Extracting features:  95%|█████████▍| 93/98 [03:46<00:12,  2.56s/it]
#
# Extracting features:  96%|█████████▌| 94/98 [03:49<00:10,  2.52s/it]
#
# Extracting features:  97%|█████████▋| 95/98 [03:51<00:07,  2.50s/it]
#
# Extracting features:  98%|█████████▊| 96/98 [03:54<00:04,  2.50s/it]
#
# Extracting features:  99%|█████████▉| 97/98 [03:56<00:02,  2.48s/it]
#
# Extracting features: 100%|██████████| 98/98 [03:58<00:00,  2.43s/it]
#
#
# Extracting features:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Extracting features:   5%|▌         | 1/20 [00:02<00:45,  2.41s/it]
#
# Extracting features:  10%|█         | 2/20 [00:04<00:43,  2.42s/it]
#
# Extracting features:  15%|█▌        | 3/20 [00:07<00:41,  2.43s/it]
#
# Extracting features:  20%|██        | 4/20 [00:09<00:39,  2.45s/it]
#
# Extracting features:  25%|██▌       | 5/20 [00:12<00:38,  2.57s/it]
#
# Extracting features:  30%|███       | 6/20 [00:14<00:35,  2.52s/it]
#
# Extracting features:  35%|███▌      | 7/20 [00:17<00:32,  2.50s/it]
#
# Extracting features:  40%|████      | 8/20 [00:19<00:29,  2.49s/it]
#
# Extracting features:  45%|████▌     | 9/20 [00:22<00:27,  2.50s/it]
#
# Extracting features:  50%|█████     | 10/20 [00:25<00:25,  2.59s/it]
#
# Extracting features:  55%|█████▌    | 11/20 [00:27<00:22,  2.54s/it]
#
# Extracting features:  60%|██████    | 12/20 [00:30<00:20,  2.51s/it]
#
# Extracting features:  65%|██████▌   | 13/20 [00:32<00:17,  2.48s/it]
#
# Extracting features:  70%|███████   | 14/20 [00:34<00:14,  2.48s/it]
#
# Extracting features:  75%|███████▌  | 15/20 [00:37<00:12,  2.56s/it]
#
# Extracting features:  80%|████████  | 16/20 [00:40<00:10,  2.52s/it]
#
# Extracting features:  85%|████████▌ | 17/20 [00:42<00:07,  2.49s/it]
#
# Extracting features:  90%|█████████ | 18/20 [00:45<00:04,  2.48s/it]
#
# Extracting features:  95%|█████████▌| 19/20 [00:47<00:02,  2.47s/it]
#
# Extracting features: 100%|██████████| 20/20 [00:48<00:00,  2.45s/it]
#
#
# Classifying train samples:   0%|          | 0/50000 [00:00<?, ?it/s]
#
# Classifying train samples:   0%|          | 1/50000 [00:00<2:23:32,  5.81it/s]
#
# Classifying train samples:   0%|          | 2/50000 [00:00<2:30:08,  5.55it/s]
#
# Classifying train samples:   0%|          | 3/50000 [00:00<2:32:28,  5.47it/s]
#
# Classifying train samples:   0%|          | 4/50000 [00:00<2:33:07,  5.44it/s]
#
# Classifying train samples:   0%|          | 5/50000 [00:00<2:36:48,  5.31it/s]
#
# Classifying train samples:   0%|          | 6/50000 [00:01<2:34:37,  5.39it/s]
#
# Classifying train samples:   0%|          | 7/50000 [00:01<2:34:59,  5.38it/s]
#
# Classifying train samples:   0%|          | 8/50000 [00:01<2:36:10,  5.33it/s]
#
# Classifying train samples:   0%|          | 9/50000 [00:01<2:33:31,  5.43it/s]
#
# Classifying train samples:   0%|          | 10/50000 [00:01<2:41:02,  5.17it/s]
#
# Classifying train samples:   0%|          | 11/50000 [00:02<2:38:14,  5.27it/s]
#
# Classifying train samples:   0%|          | 12/50000 [00:02<2:36:38,  5.32it/s]
#
# Classifying train samples:   0%|          | 13/50000 [00:02<2:37:47,  5.28it/s]
#
# Classifying train samples:   0%|          | 14/50000 [00:02<2:38:20,  5.26it/s]
#
# Classifying train samples:   0%|          | 15/50000 [00:02<2:37:42,  5.28it/s]
#
# Classifying train samples:   0%|          | 16/50000 [00:03<2:42:08,  5.14it/s]
#
# Classifying train samples:   0%|          | 17/50000 [00:03<2:50:05,  4.90it/s]
#
# Classifying train samples:   0%|          | 18/50000 [00:03<2:50:56,  4.87it/s]
#
# Classifying train samples:   0%|          | 19/50000 [00:03<2:49:25,  4.92it/s]
#
# Classifying train samples:   0%|          | 20/50000 [00:03<2:49:01,  4.93it/s]
#
# Classifying train samples:   0%|          | 21/50000 [00:04<2:54:49,  4.76it/s]
#
# Classifying train samples:   0%|          | 22/50000 [00:04<2:53:00,  4.81it/s]
#
# Classifying train samples:   0%|          | 23/50000 [00:04<2:51:26,  4.86it/s]
#
# Classifying train samples:   0%|          | 24/50000 [00:04<2:50:13,  4.89it/s]
#
# Classifying train samples:   0%|          | 25/50000 [00:04<2:46:37,  5.00it/s]
#
# Classifying train samples:   0%|          | 26/50000 [00:05<2:49:24,  4.92it/s]
#
# Classifying train samples:   0%|          | 27/50000 [00:05<2:43:52,  5.08it/s]
#
# Classifying train samples:   0%|          | 28/50000 [00:05<2:42:15,  5.13it/s]
#
# Classifying train samples:   0%|          | 29/50000 [00:05<2:42:25,  5.13it/s]
#
# Classifying train samples:   0%|          | 30/50000 [00:05<2:43:18,  5.10it/s]
#
# Classifying train samples:   0%|          | 31/50000 [00:06<2:46:35,  5.00it/s]
#
# Classifying train samples:   0%|          | 32/50000 [00:06<2:43:07,  5.11it/s]
#
# Classifying train samples:   0%|          | 33/50000 [00:06<2:38:21,  5.26it/s]
#
# Classifying train samples:   0%|          | 34/50000 [00:06<2:38:51,  5.24it/s]
#
# Classifying train samples:   0%|          | 35/50000 [00:06<2:41:16,  5.16it/s]
#
# Classifying train samples:   0%|          | 36/50000 [00:07<2:46:45,  4.99it/s]
#
# Classifying train samples:   0%|          | 37/50000 [00:07<2:43:33,  5.09it/s]
#
# Classifying train samples:   0%|          | 38/50000 [00:07<2:41:50,  5.15it/s]
#
# Classifying train samples:   0%|          | 39/50000 [00:07<2:41:42,  5.15it/s]
#
# Classifying train samples:   0%|          | 40/50000 [00:07<2:40:58,  5.17it/s]
#
# Classifying train samples:   0%|          | 41/50000 [00:07<2:42:09,  5.13it/s]
#
# Classifying train samples:   0%|          | 42/50000 [00:08<2:44:58,  5.05it/s]
#
# Classifying train samples:   0%|          | 43/50000 [00:08<2:46:09,  5.01it/s]
#
# Classifying train samples:   0%|          | 44/50000 [00:08<2:48:20,  4.95it/s]
#
# Classifying train samples:   0%|          | 45/50000 [00:08<2:45:51,  5.02it/s]
#
# Classifying train samples:   0%|          | 46/50000 [00:08<2:43:48,  5.08it/s]
#
# Classifying train samples:   0%|          | 47/50000 [00:09<2:46:58,  4.99it/s]
#
# Classifying train samples:   0%|          | 48/50000 [00:09<2:46:29,  5.00it/s]
#
# Classifying train samples:   0%|          | 49/50000 [00:09<2:41:12,  5.16it/s]
#
# Classifying train samples:   0%|          | 50/50000 [00:09<2:46:17,  5.01it/s]
#
# Classifying train samples:   0%|          | 51/50000 [00:10<3:32:40,  3.91it/s]
#
# Classifying train samples:   0%|          | 52/50000 [00:10<4:22:16,  3.17it/s]
#
# Classifying train samples:   0%|          | 53/50000 [00:11<4:56:12,  2.81it/s]
#
# Classifying train samples:   0%|          | 54/50000 [00:11<5:12:12,  2.67it/s]
#
# Classifying train samples:   0%|          | 55/50000 [00:11<5:31:25,  2.51it/s]
#
# Classifying train samples:   0%|          | 56/50000 [00:12<5:40:07,  2.45it/s]
#
# Classifying train samples:   0%|          | 57/50000 [00:12<5:33:04,  2.50it/s]
#
# Classifying train samples:   0%|          | 58/50000 [00:13<5:04:53,  2.73it/s]
#
# Classifying train samples:   0%|          | 59/50000 [00:13<4:26:48,  3.12it/s]
#
# Classifying train samples:   0%|          | 60/50000 [00:13<3:53:19,  3.57it/s]
#
# Classifying train samples:   0%|          | 61/50000 [00:13<3:31:40,  3.93it/s]
#
# Classifying train samples:   0%|          | 62/50000 [00:13<3:16:03,  4.25it/s]
#
# Classifying train samples:   0%|          | 63/50000 [00:14<3:04:35,  4.51it/s]
#
# Classifying train samples:   0%|          | 64/50000 [00:14<3:01:52,  4.58it/s]
#
# Classifying train samples:   0%|          | 65/50000 [00:14<2:57:11,  4.70it/s]
#
# Classifying train samples:   0%|          | 66/50000 [00:14<2:58:39,  4.66it/s]
#
# Classifying train samples:   0%|          | 67/50000 [00:14<2:52:47,  4.82it/s]
#
# Classifying train samples:   0%|          | 68/50000 [00:15<2:54:01,  4.78it/s]
#
# Classifying train samples:   0%|          | 69/50000 [00:15<2:54:48,  4.76it/s]
#
# Classifying train samples:   0%|          | 70/50000 [00:15<2:58:09,  4.67it/s]
#
# Classifying train samples:   0%|          | 71/50000 [00:15<2:55:08,  4.75it/s]
#
# Classifying train samples:   0%|          | 72/50000 [00:15<2:50:20,  4.89it/s]
#
# Classifying train samples:   0%|          | 73/50000 [00:16<2:45:49,  5.02it/s]
#
# Classifying train samples:   0%|          | 74/50000 [00:16<2:44:42,  5.05it/s]
#
# Classifying train samples:   0%|          | 75/50000 [00:16<2:47:34,  4.97it/s]
#
# Classifying train samples:   0%|          | 76/50000 [00:16<2:48:01,  4.95it/s]
#
# Classifying train samples:   0%|          | 77/50000 [00:16<2:45:43,  5.02it/s]
#
# Classifying train samples:   0%|          | 78/50000 [00:17<2:45:20,  5.03it/s]
#
# Classifying train samples:   0%|          | 79/50000 [00:17<2:43:53,  5.08it/s]
#
# Classifying train samples:   0%|          | 80/50000 [00:17<2:47:28,  4.97it/s]
#
# Classifying train samples:   0%|          | 81/50000 [00:17<2:45:38,  5.02it/s]
#
# Classifying train samples:   0%|          | 82/50000 [00:17<2:45:05,  5.04it/s]
#
# Classifying train samples:   0%|          | 83/50000 [00:18<2:44:19,  5.06it/s]
#
# Classifying train samples:   0%|          | 84/50000 [00:18<2:44:31,  5.06it/s]
#
# Classifying train samples:   0%|          | 85/50000 [00:18<2:46:25,  5.00it/s]
#
# Classifying train samples:   0%|          | 86/50000 [00:18<2:53:29,  4.79it/s]
#
# Classifying train samples:   0%|          | 87/50000 [00:18<2:46:54,  4.98it/s]
#
# Classifying train samples:   0%|          | 88/50000 [00:19<2:43:02,  5.10it/s]
#
# Classifying train samples:   0%|          | 89/50000 [00:19<2:39:24,  5.22it/s]
#
# Classifying train samples:   0%|          | 90/50000 [00:19<2:45:01,  5.04it/s]
#
# Classifying train samples:   0%|          | 91/50000 [00:19<2:44:29,  5.06it/s]
#
# Classifying train samples:   0%|          | 92/50000 [00:19<2:44:32,  5.06it/s]
#
# Classifying train samples:   0%|          | 93/50000 [00:20<2:40:14,  5.19it/s]
#
# Classifying train samples:   0%|          | 94/50000 [00:20<2:38:31,  5.25it/s]
#
# Classifying train samples:   0%|          | 95/50000 [00:20<2:33:42,  5.41it/s]
#
# Classifying train samples:   0%|          | 96/50000 [00:20<2:40:17,  5.19it/s]
#
# Classifying train samples:   0%|          | 97/50000 [00:20<2:39:43,  5.21it/s]
#
# Classifying train samples:   0%|          | 98/50000 [00:20<2:38:55,  5.23it/s]
#
# Classifying train samples:   0%|          | 99/50000 [00:21<2:36:46,  5.30it/s]
#
# Classifying train samples:   0%|          | 100/50000 [00:21<2:36:04,  5.33it/s]
#
# Classifying train samples:   0%|          | 101/50000 [00:21<2:37:45,  5.27it/s]
#
# Classifying train samples:   0%|          | 102/50000 [00:21<2:40:21,  5.19it/s]
#
# Classifying train samples:   0%|          | 103/50000 [00:21<2:38:14,  5.26it/s]
#
# Classifying train samples:   0%|          | 104/50000 [00:22<2:39:13,  5.22it/s]
#
# Classifying train samples:   0%|          | 105/50000 [00:22<2:39:52,  5.20it/s]
#
# Classifying train samples:   0%|          | 106/50000 [00:22<2:42:34,  5.12it/s]
#
# Classifying train samples:   0%|          | 107/50000 [00:22<2:42:49,  5.11it/s]
#
# Classifying train samples:   0%|          | 108/50000 [00:22<2:39:28,  5.21it/s]
#
# Classifying train samples:   0%|          | 109/50000 [00:23<3:10:00,  4.38it/s]
#
# Classifying train samples:   0%|          | 110/50000 [00:23<4:00:37,  3.46it/s]
#
# Classifying train samples:   0%|          | 111/50000 [00:24<4:36:52,  3.00it/s]
#
# Classifying train samples:   0%|          | 112/50000 [00:24<5:04:30,  2.73it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-60b54aec4eab> in <cell line: 71>()
#      69     return min(distances, key=distances.get)
#      70
# ---> 71 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      72 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      73
#
# <ipython-input-5-60b54aec4eab> in <listcomp>(.0)
#      69     return min(distances, key=distances.get)
#      70
# ---> 71 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      72 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      73
#
# <ipython-input-5-60b54aec4eab> in classify_sample(x)
#      66     distances = {}
#      67     for c in classes:
# ---> 68         distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
#      69     return min(distances, key=distances.get)
#      70
#
# <ipython-input-5-60b54aec4eab> in mahalanobis_distance(x, mean, cov_matrix)
#      61
#      62 def mahalanobis_distance(x, mean, cov_matrix):
# ---> 63     return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))
#      64
#      65 def classify_sample(x):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     550     signature = 'D->D' if isComplexType(t) else 'd->d'
#     551     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553     return wrap(ainv.astype(result_t, copy=False))
#     554
#
# KeyboardInterrupt:

# %%
import numpy as np
import torch
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from scipy.spatial import distance
from tqdm import tqdm
import timm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 1. 加载 CIFAR-10 数据集
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 调整为预训练模型所需的尺寸
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=512, shuffle=False)

test_dataset = CIFAR10(root='./data', train=False, download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=512, shuffle=False)

# 2. 使用 ResNet-50 的 layer2 作为特征提取层
model = timm.create_model('resnet50', pretrained=True).to(device)
children_list = list(model.children())
selected_layer = torch.nn.Sequential(*children_list[:-4])
gap = torch.nn.AdaptiveAvgPool2d(1)
feature_extractor = torch.nn.Sequential(selected_layer, gap, torch.nn.Flatten()).to(device).eval()

def extract_features(dataloader):
    features = []
    labels = []
    with torch.no_grad():
        for inputs, targets in tqdm(dataloader, desc="Extracting features"):
            inputs = inputs.to(device)
            outputs = feature_extractor(inputs)
            features.append(outputs.cpu().numpy())
            labels.append(targets.numpy())
    return np.vstack(features), np.concatenate(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels = extract_features(test_loader)

# 3. 使用最小 Mahalanobis 距离分类器进行分类
class_means = {}
class_cov_matrices = {}
classes = np.unique(train_labels)

regularization_factor = 1e-6
for c in classes:
    class_data = train_features[train_labels == c]
    class_means[c] = np.mean(class_data, axis=0)
    class_cov_matrices[c] = np.cov(class_data, rowvar=False) + np.eye(class_data.shape[1]) * regularization_factor

def mahalanobis_distance(x, mean, cov_matrix):
    return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))

def classify_sample(x):
    distances = {}
    for c in classes:
        distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
    return min(distances, key=distances.get)

train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])

# 计算训练和测试的分类准确率
train_accuracy = np.mean(train_pred == train_labels)
test_accuracy = np.mean(test_pred == test_labels)
print(f"Training accuracy using minimum Mahalanobis distance classifier after feature extraction: {train_accuracy:.4f}")
print(f"Test accuracy using minimum Mahalanobobis distance classifier after feature extraction: {test_accuracy:.4f}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Extracting features:   0%|          | 0/98 [00:00<?, ?it/s]
#
#
# Extracting features:   1%|          | 1/98 [00:01<03:12,  1.98s/it]
#
#
# Extracting features:   2%|▏         | 2/98 [00:03<02:50,  1.78s/it]
#
#
# Extracting features:   3%|▎         | 3/98 [00:05<02:42,  1.71s/it]
#
#
# Extracting features:   4%|▍         | 4/98 [00:06<02:38,  1.68s/it]
#
#
# Extracting features:   5%|▌         | 5/98 [00:08<02:34,  1.66s/it]
#
#
# Extracting features:   6%|▌         | 6/98 [00:10<02:32,  1.66s/it]
#
#
# Extracting features:   7%|▋         | 7/98 [00:11<02:30,  1.66s/it]
#
#
# Extracting features:   8%|▊         | 8/98 [00:13<02:38,  1.77s/it]
#
#
# Extracting features:   9%|▉         | 9/98 [00:15<02:36,  1.76s/it]
#
#
# Extracting features:  10%|█         | 10/98 [00:17<02:31,  1.72s/it]
#
#
# Extracting features:  11%|█         | 11/98 [00:18<02:26,  1.69s/it]
#
#
# Extracting features:  12%|█▏        | 12/98 [00:20<02:23,  1.67s/it]
#
#
# Extracting features:  13%|█▎        | 13/98 [00:22<02:21,  1.66s/it]
#
#
# Extracting features:  14%|█▍        | 14/98 [00:23<02:19,  1.66s/it]
#
#
# Extracting features:  15%|█▌        | 15/98 [00:25<02:20,  1.70s/it]
#
#
# Extracting features:  16%|█▋        | 16/98 [00:27<02:24,  1.77s/it]
#
#
# Extracting features:  17%|█▋        | 17/98 [00:29<02:20,  1.73s/it]
#
#
# Extracting features:  18%|█▊        | 18/98 [00:30<02:15,  1.70s/it]
#
#
# Extracting features:  19%|█▉        | 19/98 [00:32<02:12,  1.67s/it]
#
#
# Extracting features:  20%|██        | 20/98 [00:33<02:10,  1.67s/it]
#
#
# Extracting features:  21%|██▏       | 21/98 [00:35<02:07,  1.66s/it]
#
#
# Extracting features:  22%|██▏       | 22/98 [00:37<02:05,  1.65s/it]
#
#
# Extracting features:  23%|██▎       | 23/98 [00:39<02:11,  1.76s/it]
#
#
# Extracting features:  24%|██▍       | 24/98 [00:40<02:07,  1.72s/it]
#
#
# Extracting features:  26%|██▌       | 25/98 [00:42<02:03,  1.70s/it]
#
#
# Extracting features:  27%|██▋       | 26/98 [00:44<02:00,  1.68s/it]
#
#
# Extracting features:  28%|██▊       | 27/98 [00:45<01:58,  1.67s/it]
#
#
# Extracting features:  29%|██▊       | 28/98 [00:47<01:56,  1.67s/it]
#
#
# Extracting features:  30%|██▉       | 29/98 [00:49<01:54,  1.66s/it]
#
#
# Extracting features:  31%|███       | 30/98 [00:51<01:59,  1.75s/it]
#
#
# Extracting features:  32%|███▏      | 31/98 [00:52<01:57,  1.76s/it]
#
#
# Extracting features:  33%|███▎      | 32/98 [00:54<01:54,  1.73s/it]
#
#
# Extracting features:  34%|███▎      | 33/98 [00:56<01:51,  1.71s/it]
#
#
# Extracting features:  35%|███▍      | 34/98 [00:57<01:48,  1.69s/it]
#
#
# Extracting features:  36%|███▌      | 35/98 [00:59<01:45,  1.67s/it]
#
#
# Extracting features:  37%|███▋      | 36/98 [01:01<01:43,  1.66s/it]
#
#
# Extracting features:  38%|███▊      | 37/98 [01:02<01:43,  1.70s/it]
#
#
# Extracting features:  39%|███▉      | 38/98 [01:04<01:47,  1.79s/it]
#
#
# Extracting features:  40%|███▉      | 39/98 [01:06<01:43,  1.75s/it]
#
#
# Extracting features:  41%|████      | 40/98 [01:08<01:39,  1.72s/it]
#
#
# Extracting features:  42%|████▏     | 41/98 [01:09<01:36,  1.69s/it]
#
#
# Extracting features:  43%|████▎     | 42/98 [01:11<01:34,  1.68s/it]
#
#
# Extracting features:  44%|████▍     | 43/98 [01:13<01:32,  1.68s/it]
#
#
# Extracting features:  45%|████▍     | 44/98 [01:14<01:30,  1.68s/it]
#
#
# Extracting features:  46%|████▌     | 45/98 [01:16<01:33,  1.77s/it]
#
#
# Extracting features:  47%|████▋     | 46/98 [01:18<01:30,  1.73s/it]
#
#
# Extracting features:  48%|████▊     | 47/98 [01:20<01:26,  1.70s/it]
#
#
# Extracting features:  49%|████▉     | 48/98 [01:21<01:24,  1.69s/it]
#
#
# Extracting features:  50%|█████     | 49/98 [01:23<01:22,  1.68s/it]
#
#
# Extracting features:  51%|█████     | 50/98 [01:25<01:19,  1.66s/it]
#
#
# Extracting features:  52%|█████▏    | 51/98 [01:26<01:17,  1.66s/it]
#
#
# Extracting features:  53%|█████▎    | 52/98 [01:28<01:20,  1.75s/it]
#
#
# Extracting features:  54%|█████▍    | 53/98 [01:30<01:18,  1.75s/it]
#
#
# Extracting features:  55%|█████▌    | 54/98 [01:32<01:15,  1.72s/it]
#
#
# Extracting features:  56%|█████▌    | 55/98 [01:33<01:13,  1.70s/it]
#
#
# Extracting features:  57%|█████▋    | 56/98 [01:35<01:11,  1.69s/it]
#
#
# Extracting features:  58%|█████▊    | 57/98 [01:37<01:08,  1.68s/it]
#
#
# Extracting features:  59%|█████▉    | 58/98 [01:38<01:06,  1.67s/it]
#
#
# Extracting features:  60%|██████    | 59/98 [01:40<01:07,  1.74s/it]
#
#
# Extracting features:  61%|██████    | 60/98 [01:42<01:08,  1.80s/it]
#
#
# Extracting features:  62%|██████▏   | 61/98 [01:44<01:05,  1.76s/it]
#
#
# Extracting features:  63%|██████▎   | 62/98 [01:45<01:02,  1.73s/it]
#
#
# Extracting features:  64%|██████▍   | 63/98 [01:47<00:59,  1.71s/it]
#
#
# Extracting features:  65%|██████▌   | 64/98 [01:49<00:57,  1.69s/it]
#
#
# Extracting features:  66%|██████▋   | 65/98 [01:50<00:55,  1.68s/it]
#
#
# Extracting features:  67%|██████▋   | 66/98 [01:52<00:54,  1.70s/it]
#
#
# Extracting features:  68%|██████▊   | 67/98 [01:54<00:55,  1.79s/it]
#
#
# Extracting features:  69%|██████▉   | 68/98 [01:56<00:52,  1.75s/it]
#
#
# Extracting features:  70%|███████   | 69/98 [01:57<00:49,  1.72s/it]
#
#
# Extracting features:  71%|███████▏  | 70/98 [01:59<00:47,  1.70s/it]
#
#
# Extracting features:  72%|███████▏  | 71/98 [02:01<00:45,  1.69s/it]
#
#
# Extracting features:  73%|███████▎  | 72/98 [02:02<00:43,  1.69s/it]
#
#
# Extracting features:  74%|███████▍  | 73/98 [02:04<00:42,  1.68s/it]
#
#
# Extracting features:  76%|███████▌  | 74/98 [02:06<00:42,  1.79s/it]
#
#
# Extracting features:  77%|███████▋  | 75/98 [02:08<00:40,  1.75s/it]
#
#
# Extracting features:  78%|███████▊  | 76/98 [02:09<00:38,  1.74s/it]
#
#
# Extracting features:  79%|███████▊  | 77/98 [02:11<00:36,  1.73s/it]
#
#
# Extracting features:  80%|███████▉  | 78/98 [02:13<00:34,  1.71s/it]
#
#
# Extracting features:  81%|████████  | 79/98 [02:15<00:32,  1.71s/it]
#
#
# Extracting features:  82%|████████▏ | 80/98 [02:16<00:30,  1.70s/it]
#
#
# Extracting features:  83%|████████▎ | 81/98 [02:18<00:30,  1.79s/it]
#
#
# Extracting features:  84%|████████▎ | 82/98 [02:20<00:28,  1.76s/it]
#
#
# Extracting features:  85%|████████▍ | 83/98 [02:22<00:26,  1.74s/it]
#
#
# Extracting features:  86%|████████▌ | 84/98 [02:23<00:24,  1.72s/it]
#
#
# Extracting features:  87%|████████▋ | 85/98 [02:25<00:22,  1.70s/it]
#
#
# Extracting features:  88%|████████▊ | 86/98 [02:27<00:20,  1.69s/it]
#
#
# Extracting features:  89%|████████▉ | 87/98 [02:28<00:18,  1.69s/it]
#
#
# Extracting features:  90%|████████▉ | 88/98 [02:30<00:17,  1.78s/it]
#
#
# Extracting features:  91%|█████████ | 89/98 [02:32<00:16,  1.80s/it]
#
#
# Extracting features:  92%|█████████▏| 90/98 [02:34<00:14,  1.76s/it]
#
#
# Extracting features:  93%|█████████▎| 91/98 [02:35<00:12,  1.73s/it]
#
#
# Extracting features:  94%|█████████▍| 92/98 [02:37<00:10,  1.72s/it]
#
#
# Extracting features:  95%|█████████▍| 93/98 [02:39<00:08,  1.70s/it]
#
#
# Extracting features:  96%|█████████▌| 94/98 [02:40<00:06,  1.70s/it]
#
#
# Extracting features:  97%|█████████▋| 95/98 [02:42<00:05,  1.76s/it]
#
#
# Extracting features:  98%|█████████▊| 96/98 [02:44<00:03,  1.82s/it]
#
#
# Extracting features:  99%|█████████▉| 97/98 [02:46<00:01,  1.77s/it]
#
#
# Extracting features: 100%|██████████| 98/98 [02:47<00:00,  1.71s/it]
#
#
#
# Extracting features:   0%|          | 0/20 [00:00<?, ?it/s]
#
#
# Extracting features:   5%|▌         | 1/20 [00:01<00:31,  1.65s/it]
#
#
# Extracting features:  10%|█         | 2/20 [00:03<00:29,  1.66s/it]
#
#
# Extracting features:  15%|█▌        | 3/20 [00:04<00:28,  1.66s/it]
#
#
# Extracting features:  20%|██        | 4/20 [00:06<00:26,  1.67s/it]
#
#
# Extracting features:  25%|██▌       | 5/20 [00:08<00:27,  1.80s/it]
#
#
# Extracting features:  30%|███       | 6/20 [00:10<00:24,  1.77s/it]
#
#
# Extracting features:  35%|███▌      | 7/20 [00:12<00:22,  1.74s/it]
#
#
# Extracting features:  40%|████      | 8/20 [00:13<00:20,  1.71s/it]
#
#
# Extracting features:  45%|████▌     | 9/20 [00:15<00:18,  1.71s/it]
#
#
# Extracting features:  50%|█████     | 10/20 [00:17<00:17,  1.70s/it]
#
#
# Extracting features:  55%|█████▌    | 11/20 [00:18<00:15,  1.70s/it]
#
#
# Extracting features:  60%|██████    | 12/20 [00:20<00:14,  1.79s/it]
#
#
# Extracting features:  65%|██████▌   | 13/20 [00:22<00:12,  1.79s/it]
#
#
# Extracting features:  70%|███████   | 14/20 [00:24<00:10,  1.76s/it]
#
#
# Extracting features:  75%|███████▌  | 15/20 [00:26<00:08,  1.75s/it]
#
#
# Extracting features:  80%|████████  | 16/20 [00:27<00:06,  1.72s/it]
#
#
# Extracting features:  85%|████████▌ | 17/20 [00:29<00:05,  1.71s/it]
#
#
# Extracting features:  90%|█████████ | 18/20 [00:31<00:03,  1.70s/it]
#
#
# Extracting features:  95%|█████████▌| 19/20 [00:33<00:01,  1.79s/it]
#
#
# Extracting features: 100%|██████████| 20/20 [00:34<00:00,  1.70s/it]
#
#
#
# Classifying train samples:   0%|          | 0/50000 [00:00<?, ?it/s]
#
#
# Classifying train samples:   0%|          | 1/50000 [00:00<2:58:18,  4.67it/s]
#
#
# Classifying train samples:   0%|          | 2/50000 [00:00<2:49:50,  4.91it/s]
#
#
# Classifying train samples:   0%|          | 3/50000 [00:00<2:47:30,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 4/50000 [00:00<2:47:07,  4.99it/s]
#
#
# Classifying train samples:   0%|          | 5/50000 [00:01<2:48:29,  4.95it/s]
#
#
# Classifying train samples:   0%|          | 6/50000 [00:01<2:52:23,  4.83it/s]
#
#
# Classifying train samples:   0%|          | 7/50000 [00:01<2:49:38,  4.91it/s]
#
#
# Classifying train samples:   0%|          | 8/50000 [00:01<2:46:15,  5.01it/s]
#
#
# Classifying train samples:   0%|          | 9/50000 [00:01<2:42:48,  5.12it/s]
#
#
# Classifying train samples:   0%|          | 10/50000 [00:01<2:42:04,  5.14it/s]
#
#
# Classifying train samples:   0%|          | 11/50000 [00:02<2:48:00,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 12/50000 [00:02<2:46:28,  5.00it/s]
#
#
# Classifying train samples:   0%|          | 13/50000 [00:02<2:44:37,  5.06it/s]
#
#
# Classifying train samples:   0%|          | 14/50000 [00:02<2:42:29,  5.13it/s]
#
#
# Classifying train samples:   0%|          | 15/50000 [00:02<2:41:20,  5.16it/s]
#
#
# Classifying train samples:   0%|          | 16/50000 [00:03<2:44:25,  5.07it/s]
#
#
# Classifying train samples:   0%|          | 17/50000 [00:03<2:43:20,  5.10it/s]
#
#
# Classifying train samples:   0%|          | 18/50000 [00:03<2:43:49,  5.08it/s]
#
#
# Classifying train samples:   0%|          | 19/50000 [00:03<2:42:07,  5.14it/s]
#
#
# Classifying train samples:   0%|          | 20/50000 [00:03<2:48:08,  4.95it/s]
#
#
# Classifying train samples:   0%|          | 21/50000 [00:04<2:49:21,  4.92it/s]
#
#
# Classifying train samples:   0%|          | 22/50000 [00:04<2:47:51,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 23/50000 [00:04<2:46:55,  4.99it/s]
#
#
# Classifying train samples:   0%|          | 24/50000 [00:04<2:44:29,  5.06it/s]
#
#
# Classifying train samples:   0%|          | 25/50000 [00:04<2:45:43,  5.03it/s]
#
#
# Classifying train samples:   0%|          | 26/50000 [00:05<2:42:05,  5.14it/s]
#
#
# Classifying train samples:   0%|          | 27/50000 [00:05<2:44:29,  5.06it/s]
#
#
# Classifying train samples:   0%|          | 28/50000 [00:05<2:43:19,  5.10it/s]
#
#
# Classifying train samples:   0%|          | 29/50000 [00:05<2:43:16,  5.10it/s]
#
#
# Classifying train samples:   0%|          | 30/50000 [00:05<2:43:46,  5.09it/s]
#
#
# Classifying train samples:   0%|          | 31/50000 [00:06<2:41:32,  5.16it/s]
#
#
# Classifying train samples:   0%|          | 32/50000 [00:06<2:45:39,  5.03it/s]
#
#
# Classifying train samples:   0%|          | 33/50000 [00:06<2:43:52,  5.08it/s]
#
#
# Classifying train samples:   0%|          | 34/50000 [00:06<2:42:42,  5.12it/s]
#
#
# Classifying train samples:   0%|          | 35/50000 [00:06<2:48:21,  4.95it/s]
#
#
# Classifying train samples:   0%|          | 36/50000 [00:07<2:48:51,  4.93it/s]
#
#
# Classifying train samples:   0%|          | 37/50000 [00:07<2:52:31,  4.83it/s]
#
#
# Classifying train samples:   0%|          | 38/50000 [00:07<2:50:42,  4.88it/s]
#
#
# Classifying train samples:   0%|          | 39/50000 [00:07<2:46:55,  4.99it/s]
#
#
# Classifying train samples:   0%|          | 40/50000 [00:07<2:46:32,  5.00it/s]
#
#
# Classifying train samples:   0%|          | 41/50000 [00:08<2:45:24,  5.03it/s]
#
#
# Classifying train samples:   0%|          | 42/50000 [00:08<2:52:46,  4.82it/s]
#
#
# Classifying train samples:   0%|          | 43/50000 [00:08<2:48:09,  4.95it/s]
#
#
# Classifying train samples:   0%|          | 44/50000 [00:08<2:46:57,  4.99it/s]
#
#
# Classifying train samples:   0%|          | 45/50000 [00:09<3:06:43,  4.46it/s]
#
#
# Classifying train samples:   0%|          | 46/50000 [00:09<3:57:02,  3.51it/s]
#
#
# Classifying train samples:   0%|          | 47/50000 [00:09<4:44:12,  2.93it/s]
#
#
# Classifying train samples:   0%|          | 48/50000 [00:10<5:21:11,  2.59it/s]
#
#
# Classifying train samples:   0%|          | 49/50000 [00:10<5:46:59,  2.40it/s]
#
#
# Classifying train samples:   0%|          | 50/50000 [00:11<5:52:49,  2.36it/s]
#
#
# Classifying train samples:   0%|          | 51/50000 [00:11<5:47:08,  2.40it/s]
#
#
# Classifying train samples:   0%|          | 52/50000 [00:12<5:50:49,  2.37it/s]
#
#
# Classifying train samples:   0%|          | 53/50000 [00:12<5:21:23,  2.59it/s]
#
#
# Classifying train samples:   0%|          | 54/50000 [00:12<4:34:27,  3.03it/s]
#
#
# Classifying train samples:   0%|          | 55/50000 [00:12<4:02:40,  3.43it/s]
#
#
# Classifying train samples:   0%|          | 56/50000 [00:13<3:40:58,  3.77it/s]
#
#
# Classifying train samples:   0%|          | 57/50000 [00:13<3:20:44,  4.15it/s]
#
#
# Classifying train samples:   0%|          | 58/50000 [00:13<3:13:21,  4.30it/s]
#
#
# Classifying train samples:   0%|          | 59/50000 [00:13<3:02:49,  4.55it/s]
#
#
# Classifying train samples:   0%|          | 60/50000 [00:13<2:57:27,  4.69it/s]
#
#
# Classifying train samples:   0%|          | 61/50000 [00:14<2:53:12,  4.81it/s]
#
#
# Classifying train samples:   0%|          | 62/50000 [00:14<2:46:26,  5.00it/s]
#
#
# Classifying train samples:   0%|          | 63/50000 [00:14<2:41:20,  5.16it/s]
#
#
# Classifying train samples:   0%|          | 64/50000 [00:14<2:40:28,  5.19it/s]
#
#
# Classifying train samples:   0%|          | 65/50000 [00:14<2:43:04,  5.10it/s]
#
#
# Classifying train samples:   0%|          | 66/50000 [00:15<2:42:12,  5.13it/s]
#
#
# Classifying train samples:   0%|          | 67/50000 [00:15<2:40:00,  5.20it/s]
#
#
# Classifying train samples:   0%|          | 68/50000 [00:15<2:40:09,  5.20it/s]
#
#
# Classifying train samples:   0%|          | 69/50000 [00:15<2:39:50,  5.21it/s]
#
#
# Classifying train samples:   0%|          | 70/50000 [00:15<2:40:42,  5.18it/s]
#
#
# Classifying train samples:   0%|          | 71/50000 [00:16<2:42:05,  5.13it/s]
#
#
# Classifying train samples:   0%|          | 72/50000 [00:16<2:41:01,  5.17it/s]
#
#
# Classifying train samples:   0%|          | 73/50000 [00:16<2:49:02,  4.92it/s]
#
#
# Classifying train samples:   0%|          | 74/50000 [00:16<2:52:16,  4.83it/s]
#
#
# Classifying train samples:   0%|          | 75/50000 [00:16<2:47:05,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 76/50000 [00:17<2:43:07,  5.10it/s]
#
#
# Classifying train samples:   0%|          | 77/50000 [00:17<2:39:14,  5.22it/s]
#
#
# Classifying train samples:   0%|          | 78/50000 [00:17<2:41:35,  5.15it/s]
#
#
# Classifying train samples:   0%|          | 79/50000 [00:17<2:37:42,  5.28it/s]
#
#
# Classifying train samples:   0%|          | 80/50000 [00:17<2:42:54,  5.11it/s]
#
#
# Classifying train samples:   0%|          | 81/50000 [00:17<2:38:10,  5.26it/s]
#
#
# Classifying train samples:   0%|          | 82/50000 [00:18<2:41:24,  5.15it/s]
#
#
# Classifying train samples:   0%|          | 83/50000 [00:18<2:39:03,  5.23it/s]
#
#
# Classifying train samples:   0%|          | 84/50000 [00:18<2:36:32,  5.31it/s]
#
#
# Classifying train samples:   0%|          | 85/50000 [00:18<2:47:12,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 86/50000 [00:18<2:51:36,  4.85it/s]
#
#
# Classifying train samples:   0%|          | 87/50000 [00:19<2:48:41,  4.93it/s]
#
#
# Classifying train samples:   0%|          | 88/50000 [00:19<2:45:07,  5.04it/s]
#
#
# Classifying train samples:   0%|          | 89/50000 [00:19<2:44:03,  5.07it/s]
#
#
# Classifying train samples:   0%|          | 90/50000 [00:19<2:48:20,  4.94it/s]
#
#
# Classifying train samples:   0%|          | 91/50000 [00:19<2:48:26,  4.94it/s]
#
#
# Classifying train samples:   0%|          | 92/50000 [00:20<2:49:35,  4.90it/s]
#
#
# Classifying train samples:   0%|          | 93/50000 [00:20<2:47:06,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 94/50000 [00:20<2:52:31,  4.82it/s]
#
#
# Classifying train samples:   0%|          | 95/50000 [00:20<2:49:40,  4.90it/s]
#
#
# Classifying train samples:   0%|          | 96/50000 [00:20<2:47:48,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 97/50000 [00:21<2:46:46,  4.99it/s]
#
#
# Classifying train samples:   0%|          | 98/50000 [00:21<2:45:00,  5.04it/s]
#
#
# Classifying train samples:   0%|          | 99/50000 [00:21<2:43:17,  5.09it/s]
#
#
# Classifying train samples:   0%|          | 100/50000 [00:21<2:46:58,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 101/50000 [00:21<2:47:09,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 102/50000 [00:22<2:45:02,  5.04it/s]
#
#
# Classifying train samples:   0%|          | 103/50000 [00:22<2:45:29,  5.03it/s]
#
#
# Classifying train samples:   0%|          | 104/50000 [00:22<3:17:42,  4.21it/s]
#
#
# Classifying train samples:   0%|          | 105/50000 [00:23<4:07:02,  3.37it/s]
#
#
# Classifying train samples:   0%|          | 106/50000 [00:23<4:46:34,  2.90it/s]
#
#
# Classifying train samples:   0%|          | 107/50000 [00:24<5:11:13,  2.67it/s]
#
#
# Classifying train samples:   0%|          | 108/50000 [00:24<5:29:43,  2.52it/s]
#
#
# Classifying train samples:   0%|          | 109/50000 [00:24<5:38:27,  2.46it/s]
#
#
# Classifying train samples:   0%|          | 110/50000 [00:25<5:42:26,  2.43it/s]
#
#
# Classifying train samples:   0%|          | 111/50000 [00:25<5:32:48,  2.50it/s]
#
#
# Classifying train samples:   0%|          | 112/50000 [00:25<4:42:37,  2.94it/s]
#
#
# Classifying train samples:   0%|          | 113/50000 [00:26<4:08:15,  3.35it/s]
#
#
# Classifying train samples:   0%|          | 114/50000 [00:26<3:44:10,  3.71it/s]
#
#
# Classifying train samples:   0%|          | 115/50000 [00:26<3:27:52,  4.00it/s]
#
#
# Classifying train samples:   0%|          | 116/50000 [00:26<3:14:22,  4.28it/s]
#
#
# Classifying train samples:   0%|          | 117/50000 [00:26<3:03:18,  4.54it/s]
#
#
# Classifying train samples:   0%|          | 118/50000 [00:27<3:00:33,  4.60it/s]
#
#
# Classifying train samples:   0%|          | 119/50000 [00:27<2:55:30,  4.74it/s]
#
#
# Classifying train samples:   0%|          | 120/50000 [00:27<2:52:10,  4.83it/s]
#
#
# Classifying train samples:   0%|          | 121/50000 [00:27<2:47:49,  4.95it/s]
#
#
# Classifying train samples:   0%|          | 122/50000 [00:27<2:47:33,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 123/50000 [00:28<2:48:38,  4.93it/s]
#
#
# Classifying train samples:   0%|          | 124/50000 [00:28<2:45:15,  5.03it/s]
#
#
# Classifying train samples:   0%|          | 125/50000 [00:28<2:44:17,  5.06it/s]
#
#
# Classifying train samples:   0%|          | 126/50000 [00:28<2:42:04,  5.13it/s]
#
#
# Classifying train samples:   0%|          | 127/50000 [00:28<2:44:13,  5.06it/s]
#
#
# Classifying train samples:   0%|          | 128/50000 [00:29<2:51:59,  4.83it/s]
#
#
# Classifying train samples:   0%|          | 129/50000 [00:29<2:50:15,  4.88it/s]
#
#
# Classifying train samples:   0%|          | 130/50000 [00:29<2:50:48,  4.87it/s]
#
#
# Classifying train samples:   0%|          | 131/50000 [00:29<2:47:09,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 132/50000 [00:29<2:47:13,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 133/50000 [00:30<2:49:12,  4.91it/s]
#
#
# Classifying train samples:   0%|          | 134/50000 [00:30<2:49:20,  4.91it/s]
#
#
# Classifying train samples:   0%|          | 135/50000 [00:30<2:46:19,  5.00it/s]
#
#
# Classifying train samples:   0%|          | 136/50000 [00:30<2:45:37,  5.02it/s]
#
#
# Classifying train samples:   0%|          | 137/50000 [00:30<2:46:28,  4.99it/s]
#
#
# Classifying train samples:   0%|          | 138/50000 [00:31<2:50:46,  4.87it/s]
#
#
# Classifying train samples:   0%|          | 139/50000 [00:31<2:49:25,  4.90it/s]
#
#
# Classifying train samples:   0%|          | 140/50000 [00:31<2:46:04,  5.00it/s]
#
#
# Classifying train samples:   0%|          | 141/50000 [00:31<2:42:56,  5.10it/s]
#
#
# Classifying train samples:   0%|          | 142/50000 [00:31<2:43:43,  5.08it/s]
#
#
# Classifying train samples:   0%|          | 143/50000 [00:32<2:50:05,  4.89it/s]
#
#
# Classifying train samples:   0%|          | 144/50000 [00:32<2:47:30,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 145/50000 [00:32<2:47:25,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 146/50000 [00:32<2:50:02,  4.89it/s]
#
#
# Classifying train samples:   0%|          | 147/50000 [00:32<2:49:21,  4.91it/s]
#
#
# Classifying train samples:   0%|          | 148/50000 [00:33<2:49:11,  4.91it/s]
#
#
# Classifying train samples:   0%|          | 149/50000 [00:33<2:50:35,  4.87it/s]
#
#
# Classifying train samples:   0%|          | 150/50000 [00:33<2:48:48,  4.92it/s]
#
#
# Classifying train samples:   0%|          | 151/50000 [00:33<2:49:39,  4.90it/s]
#
#
# Classifying train samples:   0%|          | 152/50000 [00:33<2:49:00,  4.92it/s]
#
#
# Classifying train samples:   0%|          | 153/50000 [00:34<2:48:03,  4.94it/s]
#
#
# Classifying train samples:   0%|          | 154/50000 [00:34<2:49:52,  4.89it/s]
#
#
# Classifying train samples:   0%|          | 155/50000 [00:34<2:45:14,  5.03it/s]
#
#
# Classifying train samples:   0%|          | 156/50000 [00:34<2:44:06,  5.06it/s]
#
#
# Classifying train samples:   0%|          | 157/50000 [00:34<2:45:28,  5.02it/s]
#
#
# Classifying train samples:   0%|          | 158/50000 [00:35<2:46:44,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 159/50000 [00:35<2:51:13,  4.85it/s]
#
#
# Classifying train samples:   0%|          | 160/50000 [00:35<2:50:38,  4.87it/s]
#
#
# Classifying train samples:   0%|          | 161/50000 [00:35<3:14:53,  4.26it/s]
#
#
# Classifying train samples:   0%|          | 162/50000 [00:36<4:06:12,  3.37it/s]
#
#
# Classifying train samples:   0%|          | 163/50000 [00:36<4:34:56,  3.02it/s]
#
#
# Classifying train samples:   0%|          | 164/50000 [00:37<5:02:00,  2.75it/s]
#
#
# Classifying train samples:   0%|          | 165/50000 [00:37<4:57:08,  2.80it/s]
#
#
# Classifying train samples:   0%|          | 166/50000 [00:37<5:20:47,  2.59it/s]
#
#
# Classifying train samples:   0%|          | 167/50000 [00:38<5:28:20,  2.53it/s]
#
#
# Classifying train samples:   0%|          | 168/50000 [00:38<5:25:00,  2.56it/s]
#
#
# Classifying train samples:   0%|          | 169/50000 [00:39<5:42:33,  2.42it/s]
#
#
# Classifying train samples:   0%|          | 170/50000 [00:39<5:04:24,  2.73it/s]
#
#
# Classifying train samples:   0%|          | 171/50000 [00:39<4:21:25,  3.18it/s]
#
#
# Classifying train samples:   0%|          | 172/50000 [00:39<3:51:32,  3.59it/s]
#
#
# Classifying train samples:   0%|          | 173/50000 [00:40<3:30:10,  3.95it/s]
#
#
# Classifying train samples:   0%|          | 174/50000 [00:40<3:18:04,  4.19it/s]
#
#
# Classifying train samples:   0%|          | 175/50000 [00:40<3:12:57,  4.30it/s]
#
#
# Classifying train samples:   0%|          | 176/50000 [00:40<3:02:17,  4.56it/s]
#
#
# Classifying train samples:   0%|          | 177/50000 [00:40<2:54:41,  4.75it/s]
#
#
# Classifying train samples:   0%|          | 178/50000 [00:41<2:50:35,  4.87it/s]
#
#
# Classifying train samples:   0%|          | 179/50000 [00:41<2:51:19,  4.85it/s]
#
#
# Classifying train samples:   0%|          | 180/50000 [00:41<2:52:20,  4.82it/s]
#
#
# Classifying train samples:   0%|          | 181/50000 [00:41<2:47:32,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 182/50000 [00:41<2:43:39,  5.07it/s]
#
#
# Classifying train samples:   0%|          | 183/50000 [00:42<2:39:39,  5.20it/s]
#
#
# Classifying train samples:   0%|          | 184/50000 [00:42<2:36:16,  5.31it/s]
#
#
# Classifying train samples:   0%|          | 185/50000 [00:42<2:38:12,  5.25it/s]
#
#
# Classifying train samples:   0%|          | 186/50000 [00:42<2:44:17,  5.05it/s]
#
#
# Classifying train samples:   0%|          | 187/50000 [00:42<2:41:52,  5.13it/s]
#
#
# Classifying train samples:   0%|          | 188/50000 [00:43<2:41:35,  5.14it/s]
#
#
# Classifying train samples:   0%|          | 189/50000 [00:43<2:40:58,  5.16it/s]
#
#
# Classifying train samples:   0%|          | 190/50000 [00:43<2:41:10,  5.15it/s]
#
#
# Classifying train samples:   0%|          | 191/50000 [00:43<2:45:58,  5.00it/s]
#
#
# Classifying train samples:   0%|          | 192/50000 [00:43<2:45:25,  5.02it/s]
#
#
# Classifying train samples:   0%|          | 193/50000 [00:44<2:45:51,  5.00it/s]
#
#
# Classifying train samples:   0%|          | 194/50000 [00:44<2:47:11,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 195/50000 [00:44<2:45:35,  5.01it/s]
#
#
# Classifying train samples:   0%|          | 196/50000 [00:44<2:47:00,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 197/50000 [00:44<2:44:52,  5.03it/s]
#
#
# Classifying train samples:   0%|          | 198/50000 [00:45<2:47:07,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 199/50000 [00:45<2:47:29,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 200/50000 [00:45<2:47:22,  4.96it/s]
#
#
# Classifying train samples:   0%|          | 201/50000 [00:45<2:46:40,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 202/50000 [00:45<2:46:30,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 203/50000 [00:46<2:44:24,  5.05it/s]
#
#
# Classifying train samples:   0%|          | 204/50000 [00:46<2:46:37,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 205/50000 [00:46<2:46:54,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 206/50000 [00:46<2:50:55,  4.86it/s]
#
#
# Classifying train samples:   0%|          | 207/50000 [00:46<2:48:34,  4.92it/s]
#
#
# Classifying train samples:   0%|          | 208/50000 [00:47<2:52:54,  4.80it/s]
#
#
# Classifying train samples:   0%|          | 209/50000 [00:47<2:53:21,  4.79it/s]
#
#
# Classifying train samples:   0%|          | 210/50000 [00:47<2:55:10,  4.74it/s]
#
#
# Classifying train samples:   0%|          | 211/50000 [00:47<2:54:16,  4.76it/s]
#
#
# Classifying train samples:   0%|          | 212/50000 [00:47<2:56:52,  4.69it/s]
#
#
# Classifying train samples:   0%|          | 213/50000 [00:48<2:54:21,  4.76it/s]
#
#
# Classifying train samples:   0%|          | 214/50000 [00:48<2:56:18,  4.71it/s]
#
#
# Classifying train samples:   0%|          | 215/50000 [00:48<2:52:47,  4.80it/s]
#
#
# Classifying train samples:   0%|          | 216/50000 [00:48<2:57:43,  4.67it/s]
#
#
# Classifying train samples:   0%|          | 217/50000 [00:48<2:55:05,  4.74it/s]
#
#
# Classifying train samples:   0%|          | 218/50000 [00:49<2:50:20,  4.87it/s]
#
#
# Classifying train samples:   0%|          | 219/50000 [00:49<2:59:40,  4.62it/s]
#
#
# Classifying train samples:   0%|          | 220/50000 [00:49<3:41:44,  3.74it/s]
#
#
# Classifying train samples:   0%|          | 221/50000 [00:50<4:33:14,  3.04it/s]
#
#
# Classifying train samples:   0%|          | 222/50000 [00:50<5:09:21,  2.68it/s]
#
#
# Classifying train samples:   0%|          | 223/50000 [00:51<5:31:24,  2.50it/s]
#
#
# Classifying train samples:   0%|          | 224/50000 [00:51<5:49:29,  2.37it/s]
#
#
# Classifying train samples:   0%|          | 225/50000 [00:52<5:46:41,  2.39it/s]
#
#
# Classifying train samples:   0%|          | 226/50000 [00:52<5:48:58,  2.38it/s]
#
#
# Classifying train samples:   0%|          | 227/50000 [00:52<5:34:10,  2.48it/s]
#
#
# Classifying train samples:   0%|          | 228/50000 [00:53<4:46:57,  2.89it/s]
#
#
# Classifying train samples:   0%|          | 229/50000 [00:53<4:13:57,  3.27it/s]
#
#
# Classifying train samples:   0%|          | 230/50000 [00:53<3:48:24,  3.63it/s]
#
#
# Classifying train samples:   0%|          | 231/50000 [00:53<3:26:54,  4.01it/s]
#
#
# Classifying train samples:   0%|          | 232/50000 [00:53<3:21:16,  4.12it/s]
#
#
# Classifying train samples:   0%|          | 233/50000 [00:54<3:10:16,  4.36it/s]
#
#
# Classifying train samples:   0%|          | 234/50000 [00:54<3:07:20,  4.43it/s]
#
#
# Classifying train samples:   0%|          | 235/50000 [00:54<2:58:50,  4.64it/s]
#
#
# Classifying train samples:   0%|          | 236/50000 [00:54<2:49:46,  4.89it/s]
#
#
# Classifying train samples:   0%|          | 237/50000 [00:54<2:46:56,  4.97it/s]
#
#
# Classifying train samples:   0%|          | 238/50000 [00:55<2:47:48,  4.94it/s]
#
#
# Classifying train samples:   0%|          | 239/50000 [00:55<2:49:18,  4.90it/s]
#
#
# Classifying train samples:   0%|          | 240/50000 [00:55<2:49:27,  4.89it/s]
#
#
# Classifying train samples:   0%|          | 241/50000 [00:55<2:50:49,  4.85it/s]
#
#
# Classifying train samples:   0%|          | 242/50000 [00:55<2:52:25,  4.81it/s]
#
#
# Classifying train samples:   0%|          | 243/50000 [00:56<2:52:23,  4.81it/s]
#
#
# Classifying train samples:   0%|          | 244/50000 [00:56<2:51:12,  4.84it/s]
#
#
# Classifying train samples:   0%|          | 245/50000 [00:56<2:50:34,  4.86it/s]
#
#
# Classifying train samples:   0%|          | 246/50000 [00:56<2:46:22,  4.98it/s]
#
#
# Classifying train samples:   0%|          | 247/50000 [00:56<2:44:09,  5.05it/s]
#
#
# Classifying train samples:   0%|          | 248/50000 [00:57<2:46:12,  4.99it/s]
#
#
# Classifying train samples:   0%|          | 249/50000 [00:57<2:45:39,  5.01it/s]
#
#
# Classifying train samples:   0%|          | 250/50000 [00:57<2:46:54,  4.97it/s]
#
#
# Classifying train samples:   1%|          | 251/50000 [00:57<2:44:50,  5.03it/s]
#
#
# Classifying train samples:   1%|          | 252/50000 [00:57<2:43:55,  5.06it/s]
#
#
# Classifying train samples:   1%|          | 253/50000 [00:58<2:46:35,  4.98it/s]
#
#
# Classifying train samples:   1%|          | 254/50000 [00:58<2:45:08,  5.02it/s]
#
#
# Classifying train samples:   1%|          | 255/50000 [00:58<2:42:53,  5.09it/s]
#
#
# Classifying train samples:   1%|          | 256/50000 [00:58<2:41:31,  5.13it/s]
#
#
# Classifying train samples:   1%|          | 257/50000 [00:58<2:39:01,  5.21it/s]
#
#
# Classifying train samples:   1%|          | 258/50000 [00:59<2:45:29,  5.01it/s]
#
#
# Classifying train samples:   1%|          | 259/50000 [00:59<2:45:53,  5.00it/s]
#
#
# Classifying train samples:   1%|          | 260/50000 [00:59<2:45:55,  5.00it/s]
#
#
# Classifying train samples:   1%|          | 261/50000 [00:59<2:44:54,  5.03it/s]
#
#
# Classifying train samples:   1%|          | 262/50000 [00:59<2:46:04,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 263/50000 [01:00<2:51:55,  4.82it/s]
#
#
# Classifying train samples:   1%|          | 264/50000 [01:00<2:50:39,  4.86it/s]
#
#
# Classifying train samples:   1%|          | 265/50000 [01:00<2:46:55,  4.97it/s]
#
#
# Classifying train samples:   1%|          | 266/50000 [01:00<2:44:25,  5.04it/s]
#
#
# Classifying train samples:   1%|          | 267/50000 [01:00<2:43:02,  5.08it/s]
#
#
# Classifying train samples:   1%|          | 268/50000 [01:01<2:51:17,  4.84it/s]
#
#
# Classifying train samples:   1%|          | 269/50000 [01:01<2:53:38,  4.77it/s]
#
#
# Classifying train samples:   1%|          | 270/50000 [01:01<2:52:26,  4.81it/s]
#
#
# Classifying train samples:   1%|          | 271/50000 [01:01<2:47:44,  4.94it/s]
#
#
# Classifying train samples:   1%|          | 272/50000 [01:01<2:44:14,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 273/50000 [01:02<2:45:32,  5.01it/s]
#
#
# Classifying train samples:   1%|          | 274/50000 [01:02<2:45:36,  5.00it/s]
#
#
# Classifying train samples:   1%|          | 275/50000 [01:02<2:46:33,  4.98it/s]
#
#
# Classifying train samples:   1%|          | 276/50000 [01:02<2:44:02,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 277/50000 [01:03<3:26:15,  4.02it/s]
#
#
# Classifying train samples:   1%|          | 278/50000 [01:03<4:08:43,  3.33it/s]
#
#
# Classifying train samples:   1%|          | 279/50000 [01:03<4:45:33,  2.90it/s]
#
#
# Classifying train samples:   1%|          | 280/50000 [01:04<5:07:42,  2.69it/s]
#
#
# Classifying train samples:   1%|          | 281/50000 [01:04<5:22:43,  2.57it/s]
#
#
# Classifying train samples:   1%|          | 282/50000 [01:05<5:38:28,  2.45it/s]
#
#
# Classifying train samples:   1%|          | 283/50000 [01:05<5:36:54,  2.46it/s]
#
#
# Classifying train samples:   1%|          | 284/50000 [01:06<5:34:34,  2.48it/s]
#
#
# Classifying train samples:   1%|          | 285/50000 [01:06<5:20:03,  2.59it/s]
#
#
# Classifying train samples:   1%|          | 286/50000 [01:06<4:34:54,  3.01it/s]
#
#
# Classifying train samples:   1%|          | 287/50000 [01:06<4:09:35,  3.32it/s]
#
#
# Classifying train samples:   1%|          | 288/50000 [01:07<3:46:39,  3.66it/s]
#
#
# Classifying train samples:   1%|          | 289/50000 [01:07<3:29:28,  3.96it/s]
#
#
# Classifying train samples:   1%|          | 290/50000 [01:07<3:24:53,  4.04it/s]
#
#
# Classifying train samples:   1%|          | 291/50000 [01:07<3:11:08,  4.33it/s]
#
#
# Classifying train samples:   1%|          | 292/50000 [01:07<3:04:43,  4.48it/s]
#
#
# Classifying train samples:   1%|          | 293/50000 [01:08<2:57:39,  4.66it/s]
#
#
# Classifying train samples:   1%|          | 294/50000 [01:08<2:52:09,  4.81it/s]
#
#
# Classifying train samples:   1%|          | 295/50000 [01:08<2:52:28,  4.80it/s]
#
#
# Classifying train samples:   1%|          | 296/50000 [01:08<2:50:09,  4.87it/s]
#
#
# Classifying train samples:   1%|          | 297/50000 [01:08<2:49:59,  4.87it/s]
#
#
# Classifying train samples:   1%|          | 298/50000 [01:09<2:49:11,  4.90it/s]
#
#
# Classifying train samples:   1%|          | 299/50000 [01:09<2:51:21,  4.83it/s]
#
#
# Classifying train samples:   1%|          | 300/50000 [01:09<2:52:27,  4.80it/s]
#
#
# Classifying train samples:   1%|          | 301/50000 [01:09<2:48:23,  4.92it/s]
#
#
# Classifying train samples:   1%|          | 302/50000 [01:09<2:47:02,  4.96it/s]
#
#
# Classifying train samples:   1%|          | 303/50000 [01:10<2:47:52,  4.93it/s]
#
#
# Classifying train samples:   1%|          | 304/50000 [01:10<2:49:37,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 305/50000 [01:10<2:52:25,  4.80it/s]
#
#
# Classifying train samples:   1%|          | 306/50000 [01:10<2:50:35,  4.85it/s]
#
#
# Classifying train samples:   1%|          | 307/50000 [01:10<2:50:21,  4.86it/s]
#
#
# Classifying train samples:   1%|          | 308/50000 [01:11<2:47:59,  4.93it/s]
#
#
# Classifying train samples:   1%|          | 309/50000 [01:11<2:46:11,  4.98it/s]
#
#
# Classifying train samples:   1%|          | 310/50000 [01:11<2:48:55,  4.90it/s]
#
#
# Classifying train samples:   1%|          | 311/50000 [01:11<2:45:19,  5.01it/s]
#
#
# Classifying train samples:   1%|          | 312/50000 [01:11<2:44:05,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 313/50000 [01:12<2:41:04,  5.14it/s]
#
#
# Classifying train samples:   1%|          | 314/50000 [01:12<2:38:27,  5.23it/s]
#
#
# Classifying train samples:   1%|          | 315/50000 [01:12<2:48:05,  4.93it/s]
#
#
# Classifying train samples:   1%|          | 316/50000 [01:12<2:43:23,  5.07it/s]
#
#
# Classifying train samples:   1%|          | 317/50000 [01:12<2:43:40,  5.06it/s]
#
#
# Classifying train samples:   1%|          | 318/50000 [01:13<2:38:53,  5.21it/s]
#
#
# Classifying train samples:   1%|          | 319/50000 [01:13<2:37:57,  5.24it/s]
#
#
# Classifying train samples:   1%|          | 320/50000 [01:13<2:37:00,  5.27it/s]
#
#
# Classifying train samples:   1%|          | 321/50000 [01:13<2:40:59,  5.14it/s]
#
#
# Classifying train samples:   1%|          | 322/50000 [01:13<2:42:10,  5.11it/s]
#
#
# Classifying train samples:   1%|          | 323/50000 [01:14<2:41:01,  5.14it/s]
#
#
# Classifying train samples:   1%|          | 324/50000 [01:14<2:39:46,  5.18it/s]
#
#
# Classifying train samples:   1%|          | 325/50000 [01:14<2:38:14,  5.23it/s]
#
#
# Classifying train samples:   1%|          | 326/50000 [01:14<2:45:53,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 327/50000 [01:14<2:44:46,  5.02it/s]
#
#
# Classifying train samples:   1%|          | 328/50000 [01:15<2:46:01,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 329/50000 [01:15<2:44:12,  5.04it/s]
#
#
# Classifying train samples:   1%|          | 330/50000 [01:15<2:45:07,  5.01it/s]
#
#
# Classifying train samples:   1%|          | 331/50000 [01:15<2:49:03,  4.90it/s]
#
#
# Classifying train samples:   1%|          | 332/50000 [01:15<2:48:13,  4.92it/s]
#
#
# Classifying train samples:   1%|          | 333/50000 [01:16<2:46:21,  4.98it/s]
#
#
# Classifying train samples:   1%|          | 334/50000 [01:16<2:45:07,  5.01it/s]
#
#
# Classifying train samples:   1%|          | 335/50000 [01:16<2:56:46,  4.68it/s]
#
#
# Classifying train samples:   1%|          | 336/50000 [01:16<3:46:42,  3.65it/s]
#
#
# Classifying train samples:   1%|          | 337/50000 [01:17<4:31:39,  3.05it/s]
#
#
# Classifying train samples:   1%|          | 338/50000 [01:17<5:03:39,  2.73it/s]
#
#
# Classifying train samples:   1%|          | 339/50000 [01:18<5:29:38,  2.51it/s]
#
#
# Classifying train samples:   1%|          | 340/50000 [01:18<5:44:57,  2.40it/s]
#
#
# Classifying train samples:   1%|          | 341/50000 [01:19<5:57:04,  2.32it/s]
#
#
# Classifying train samples:   1%|          | 342/50000 [01:19<5:47:43,  2.38it/s]
#
#
# Classifying train samples:   1%|          | 343/50000 [01:20<5:29:13,  2.51it/s]
#
#
# Classifying train samples:   1%|          | 344/50000 [01:20<4:41:57,  2.94it/s]
#
#
# Classifying train samples:   1%|          | 345/50000 [01:20<4:07:36,  3.34it/s]
#
#
# Classifying train samples:   1%|          | 346/50000 [01:20<3:44:26,  3.69it/s]
#
#
# Classifying train samples:   1%|          | 347/50000 [01:20<3:38:52,  3.78it/s]
#
#
# Classifying train samples:   1%|          | 348/50000 [01:21<3:22:48,  4.08it/s]
#
#
# Classifying train samples:   1%|          | 349/50000 [01:21<3:13:26,  4.28it/s]
#
#
# Classifying train samples:   1%|          | 350/50000 [01:21<3:07:21,  4.42it/s]
#
#
# Classifying train samples:   1%|          | 351/50000 [01:21<3:01:11,  4.57it/s]
#
#
# Classifying train samples:   1%|          | 352/50000 [01:21<3:01:44,  4.55it/s]
#
#
# Classifying train samples:   1%|          | 353/50000 [01:22<2:57:30,  4.66it/s]
#
#
# Classifying train samples:   1%|          | 354/50000 [01:22<2:51:26,  4.83it/s]
#
#
# Classifying train samples:   1%|          | 355/50000 [01:22<2:49:40,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 356/50000 [01:22<2:48:59,  4.90it/s]
#
#
# Classifying train samples:   1%|          | 357/50000 [01:22<2:53:37,  4.77it/s]
#
#
# Classifying train samples:   1%|          | 358/50000 [01:23<2:53:20,  4.77it/s]
#
#
# Classifying train samples:   1%|          | 359/50000 [01:23<2:49:33,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 360/50000 [01:23<2:48:02,  4.92it/s]
#
#
# Classifying train samples:   1%|          | 361/50000 [01:23<2:46:04,  4.98it/s]
#
#
# Classifying train samples:   1%|          | 362/50000 [01:23<2:51:07,  4.83it/s]
#
#
# Classifying train samples:   1%|          | 363/50000 [01:24<2:51:51,  4.81it/s]
#
#
# Classifying train samples:   1%|          | 364/50000 [01:24<2:52:39,  4.79it/s]
#
#
# Classifying train samples:   1%|          | 365/50000 [01:24<2:46:16,  4.98it/s]
#
#
# Classifying train samples:   1%|          | 366/50000 [01:24<2:50:35,  4.85it/s]
#
#
# Classifying train samples:   1%|          | 367/50000 [01:24<2:53:30,  4.77it/s]
#
#
# Classifying train samples:   1%|          | 368/50000 [01:25<2:52:24,  4.80it/s]
#
#
# Classifying train samples:   1%|          | 369/50000 [01:25<2:49:47,  4.87it/s]
#
#
# Classifying train samples:   1%|          | 370/50000 [01:25<2:52:04,  4.81it/s]
#
#
# Classifying train samples:   1%|          | 371/50000 [01:25<2:49:35,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 372/50000 [01:26<2:49:38,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 373/50000 [01:26<2:48:44,  4.90it/s]
#
#
# Classifying train samples:   1%|          | 374/50000 [01:26<2:43:49,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 375/50000 [01:26<2:43:58,  5.04it/s]
#
#
# Classifying train samples:   1%|          | 376/50000 [01:26<2:43:00,  5.07it/s]
#
#
# Classifying train samples:   1%|          | 377/50000 [01:27<2:49:03,  4.89it/s]
#
#
# Classifying train samples:   1%|          | 378/50000 [01:27<2:48:34,  4.91it/s]
#
#
# Classifying train samples:   1%|          | 379/50000 [01:27<2:46:08,  4.98it/s]
#
#
# Classifying train samples:   1%|          | 380/50000 [01:27<2:45:49,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 381/50000 [01:27<2:41:52,  5.11it/s]
#
#
# Classifying train samples:   1%|          | 382/50000 [01:27<2:44:49,  5.02it/s]
#
#
# Classifying train samples:   1%|          | 383/50000 [01:28<2:46:28,  4.97it/s]
#
#
# Classifying train samples:   1%|          | 384/50000 [01:28<2:46:13,  4.97it/s]
#
#
# Classifying train samples:   1%|          | 385/50000 [01:28<2:43:44,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 386/50000 [01:28<2:49:02,  4.89it/s]
#
#
# Classifying train samples:   1%|          | 387/50000 [01:29<2:47:41,  4.93it/s]
#
#
# Classifying train samples:   1%|          | 388/50000 [01:29<2:52:01,  4.81it/s]
#
#
# Classifying train samples:   1%|          | 389/50000 [01:29<2:50:37,  4.85it/s]
#
#
# Classifying train samples:   1%|          | 390/50000 [01:29<2:51:08,  4.83it/s]
#
#
# Classifying train samples:   1%|          | 391/50000 [01:29<2:50:19,  4.85it/s]
#
#
# Classifying train samples:   1%|          | 392/50000 [01:30<2:59:24,  4.61it/s]
#
#
# Classifying train samples:   1%|          | 393/50000 [01:30<3:44:56,  3.68it/s]
#
#
# Classifying train samples:   1%|          | 394/50000 [01:30<4:34:08,  3.02it/s]
#
#
# Classifying train samples:   1%|          | 395/50000 [01:31<5:01:04,  2.75it/s]
#
#
# Classifying train samples:   1%|          | 396/50000 [01:31<5:13:34,  2.64it/s]
#
#
# Classifying train samples:   1%|          | 397/50000 [01:32<5:31:57,  2.49it/s]
#
#
# Classifying train samples:   1%|          | 398/50000 [01:32<5:23:13,  2.56it/s]
#
#
# Classifying train samples:   1%|          | 399/50000 [01:33<5:35:00,  2.47it/s]
#
#
# Classifying train samples:   1%|          | 400/50000 [01:33<5:30:46,  2.50it/s]
#
#
# Classifying train samples:   1%|          | 401/50000 [01:33<4:41:44,  2.93it/s]
#
#
# Classifying train samples:   1%|          | 402/50000 [01:33<4:11:24,  3.29it/s]
#
#
# Classifying train samples:   1%|          | 403/50000 [01:34<3:44:50,  3.68it/s]
#
#
# Classifying train samples:   1%|          | 404/50000 [01:34<3:29:00,  3.95it/s]
#
#
# Classifying train samples:   1%|          | 405/50000 [01:34<3:20:22,  4.13it/s]
#
#
# Classifying train samples:   1%|          | 406/50000 [01:34<3:06:03,  4.44it/s]
#
#
# Classifying train samples:   1%|          | 407/50000 [01:34<3:00:55,  4.57it/s]
#
#
# Classifying train samples:   1%|          | 408/50000 [01:35<2:55:32,  4.71it/s]
#
#
# Classifying train samples:   1%|          | 409/50000 [01:35<2:53:53,  4.75it/s]
#
#
# Classifying train samples:   1%|          | 410/50000 [01:35<2:57:35,  4.65it/s]
#
#
# Classifying train samples:   1%|          | 411/50000 [01:35<2:54:08,  4.75it/s]
#
#
# Classifying train samples:   1%|          | 412/50000 [01:35<2:50:54,  4.84it/s]
#
#
# Classifying train samples:   1%|          | 413/50000 [01:36<2:48:19,  4.91it/s]
#
#
# Classifying train samples:   1%|          | 414/50000 [01:36<2:48:59,  4.89it/s]
#
#
# Classifying train samples:   1%|          | 415/50000 [01:36<2:52:35,  4.79it/s]
#
#
# Classifying train samples:   1%|          | 416/50000 [01:36<2:54:30,  4.74it/s]
#
#
# Classifying train samples:   1%|          | 417/50000 [01:36<2:56:55,  4.67it/s]
#
#
# Classifying train samples:   1%|          | 418/50000 [01:37<2:52:29,  4.79it/s]
#
#
# Classifying train samples:   1%|          | 419/50000 [01:37<2:49:56,  4.86it/s]
#
#
# Classifying train samples:   1%|          | 420/50000 [01:37<2:54:16,  4.74it/s]
#
#
# Classifying train samples:   1%|          | 421/50000 [01:37<2:53:46,  4.76it/s]
#
#
# Classifying train samples:   1%|          | 422/50000 [01:38<2:48:30,  4.90it/s]
#
#
# Classifying train samples:   1%|          | 423/50000 [01:38<2:44:09,  5.03it/s]
#
#
# Classifying train samples:   1%|          | 424/50000 [01:38<2:40:01,  5.16it/s]
#
#
# Classifying train samples:   1%|          | 425/50000 [01:38<2:45:23,  5.00it/s]
#
#
# Classifying train samples:   1%|          | 426/50000 [01:38<2:45:39,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 427/50000 [01:38<2:44:20,  5.03it/s]
#
#
# Classifying train samples:   1%|          | 428/50000 [01:39<2:46:20,  4.97it/s]
#
#
# Classifying train samples:   1%|          | 429/50000 [01:39<2:46:27,  4.96it/s]
#
#
# Classifying train samples:   1%|          | 430/50000 [01:39<2:47:43,  4.93it/s]
#
#
# Classifying train samples:   1%|          | 431/50000 [01:39<2:45:41,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 432/50000 [01:39<2:47:56,  4.92it/s]
#
#
# Classifying train samples:   1%|          | 433/50000 [01:40<2:46:42,  4.96it/s]
#
#
# Classifying train samples:   1%|          | 434/50000 [01:40<2:48:32,  4.90it/s]
#
#
# Classifying train samples:   1%|          | 435/50000 [01:40<2:50:03,  4.86it/s]
#
#
# Classifying train samples:   1%|          | 436/50000 [01:40<2:46:09,  4.97it/s]
#
#
# Classifying train samples:   1%|          | 437/50000 [01:41<2:44:24,  5.02it/s]
#
#
# Classifying train samples:   1%|          | 438/50000 [01:41<2:43:12,  5.06it/s]
#
#
# Classifying train samples:   1%|          | 439/50000 [01:41<2:43:32,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 440/50000 [01:41<2:48:51,  4.89it/s]
#
#
# Classifying train samples:   1%|          | 441/50000 [01:41<2:49:59,  4.86it/s]
#
#
# Classifying train samples:   1%|          | 442/50000 [01:42<2:47:40,  4.93it/s]
#
#
# Classifying train samples:   1%|          | 443/50000 [01:42<2:49:50,  4.86it/s]
#
#
# Classifying train samples:   1%|          | 444/50000 [01:42<2:47:08,  4.94it/s]
#
#
# Classifying train samples:   1%|          | 445/50000 [01:42<2:50:31,  4.84it/s]
#
#
# Classifying train samples:   1%|          | 446/50000 [01:42<2:47:14,  4.94it/s]
#
#
# Classifying train samples:   1%|          | 447/50000 [01:43<2:45:29,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 448/50000 [01:43<2:46:39,  4.96it/s]
#
#
# Classifying train samples:   1%|          | 449/50000 [01:43<2:45:25,  4.99it/s]
#
#
# Classifying train samples:   1%|          | 450/50000 [01:43<3:17:38,  4.18it/s]
#
#
# Classifying train samples:   1%|          | 451/50000 [01:44<4:11:43,  3.28it/s]
#
#
# Classifying train samples:   1%|          | 452/50000 [01:44<4:54:03,  2.81it/s]
#
#
# Classifying train samples:   1%|          | 453/50000 [01:45<5:12:55,  2.64it/s]
#
#
# Classifying train samples:   1%|          | 454/50000 [01:45<5:29:24,  2.51it/s]
#
#
# Classifying train samples:   1%|          | 455/50000 [01:45<5:34:58,  2.47it/s]
#
#
# Classifying train samples:   1%|          | 456/50000 [01:46<5:42:10,  2.41it/s]
#
#
# Classifying train samples:   1%|          | 457/50000 [01:46<5:48:47,  2.37it/s]
#
#
# Classifying train samples:   1%|          | 458/50000 [01:47<5:01:35,  2.74it/s]
#
#
# Classifying train samples:   1%|          | 459/50000 [01:47<4:17:33,  3.21it/s]
#
#
# Classifying train samples:   1%|          | 460/50000 [01:47<3:48:34,  3.61it/s]
#
#
# Classifying train samples:   1%|          | 461/50000 [01:47<3:30:38,  3.92it/s]
#
#
# Classifying train samples:   1%|          | 462/50000 [01:47<3:29:47,  3.94it/s]
#
#
# Classifying train samples:   1%|          | 463/50000 [01:48<3:20:16,  4.12it/s]
#
#
# Classifying train samples:   1%|          | 464/50000 [01:48<3:09:31,  4.36it/s]
#
#
# Classifying train samples:   1%|          | 465/50000 [01:48<3:01:26,  4.55it/s]
#
#
# Classifying train samples:   1%|          | 466/50000 [01:48<2:57:57,  4.64it/s]
#
#
# Classifying train samples:   1%|          | 467/50000 [01:48<3:01:06,  4.56it/s]
#
#
# Classifying train samples:   1%|          | 468/50000 [01:49<2:56:02,  4.69it/s]
#
#
# Classifying train samples:   1%|          | 469/50000 [01:49<2:50:24,  4.84it/s]
#
#
# Classifying train samples:   1%|          | 470/50000 [01:49<2:48:04,  4.91it/s]
#
#
# Classifying train samples:   1%|          | 471/50000 [01:49<2:43:20,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 472/50000 [01:49<2:46:22,  4.96it/s]
#
#
# Classifying train samples:   1%|          | 473/50000 [01:50<2:44:45,  5.01it/s]
#
#
# Classifying train samples:   1%|          | 474/50000 [01:50<2:49:17,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 475/50000 [01:50<2:51:34,  4.81it/s]
#
#
# ...
#
#
# Classifying train samples:   1%|          | 580/50000 [02:16<2:50:33,  4.83it/s]
#
#
# Classifying train samples:   1%|          | 581/50000 [02:16<2:46:39,  4.94it/s]
#
#
# Classifying train samples:   1%|          | 582/50000 [02:16<2:46:18,  4.95it/s]
#
#
# Classifying train samples:   1%|          | 583/50000 [02:17<2:52:18,  4.78it/s]
#
#
# Classifying train samples:   1%|          | 584/50000 [02:17<2:51:34,  4.80it/s]
#
#
# Classifying train samples:   1%|          | 585/50000 [02:17<2:48:42,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 586/50000 [02:17<2:49:47,  4.85it/s]
#
#
# Classifying train samples:   1%|          | 587/50000 [02:17<2:50:04,  4.84it/s]
#
#
# Classifying train samples:   1%|          | 588/50000 [02:18<3:02:29,  4.51it/s]
#
#
# Classifying train samples:   1%|          | 589/50000 [02:18<3:06:36,  4.41it/s]
#
#
# Classifying train samples:   1%|          | 590/50000 [02:18<3:02:19,  4.52it/s]
#
#
# Classifying train samples:   1%|          | 591/50000 [02:18<3:04:46,  4.46it/s]
#
#
# Classifying train samples:   1%|          | 592/50000 [02:19<3:10:54,  4.31it/s]
#
#
# Classifying train samples:   1%|          | 593/50000 [02:19<3:02:05,  4.52it/s]
#
#
# Classifying train samples:   1%|          | 594/50000 [02:19<2:58:04,  4.62it/s]
#
#
# Classifying train samples:   1%|          | 595/50000 [02:19<2:53:51,  4.74it/s]
#
#
# Classifying train samples:   1%|          | 596/50000 [02:19<2:50:46,  4.82it/s]
#
#
# Classifying train samples:   1%|          | 597/50000 [02:20<2:52:09,  4.78it/s]
#
#
# Classifying train samples:   1%|          | 598/50000 [02:20<2:53:19,  4.75it/s]
#
#
# Classifying train samples:   1%|          | 599/50000 [02:20<2:48:51,  4.88it/s]
#
#
# Classifying train samples:   1%|          | 600/50000 [02:20<2:46:00,  4.96it/s]
#
#
# Classifying train samples:   1%|          | 601/50000 [02:20<2:42:25,  5.07it/s]
#
#
# Classifying train samples:   1%|          | 602/50000 [02:21<2:57:27,  4.64it/s]
#
#
# Classifying train samples:   1%|          | 603/50000 [02:21<2:52:36,  4.77it/s]
#
#
# Classifying train samples:   1%|          | 604/50000 [02:21<2:47:22,  4.92it/s]
#
#
# Classifying train samples:   1%|          | 605/50000 [02:21<2:43:14,  5.04it/s]
#
#
# Classifying train samples:   1%|          | 606/50000 [02:21<2:42:24,  5.07it/s]
#
#
# Classifying train samples:   1%|          | 607/50000 [02:22<2:42:44,  5.06it/s]
#
#
# Classifying train samples:   1%|          | 608/50000 [02:22<2:44:39,  5.00it/s]
#
#
# Classifying train samples:   1%|          | 609/50000 [02:22<2:45:48,  4.96it/s]
#
#
# Classifying train samples:   1%|          | 610/50000 [02:22<2:43:07,  5.05it/s]
#
#
# Classifying train samples:   1%|          | 611/50000 [02:22<2:41:54,  5.08it/s]
#
#
# Classifying train samples:   1%|          | 612/50000 [02:23<2:40:39,  5.12it/s]
#
#
# Classifying train samples:   1%|          | 613/50000 [02:23<2:48:54,  4.87it/s]
#
#
# Classifying train samples:   1%|          | 614/50000 [02:23<2:46:33,  4.94it/s]
#
#
# Classifying train samples:   1%|          | 615/50000 [02:23<2:47:33,  4.91it/s]
#
#
# Classifying train samples:   1%|          | 616/50000 [02:23<2:52:48,  4.76it/s]
#
#
# Classifying train samples:   1%|          | 617/50000 [02:24<3:40:15,  3.74it/s]
#
#
# Classifying train samples:   1%|          | 618/50000 [02:24<4:19:50,  3.17it/s]
#
#
# Classifying train samples:   1%|          | 619/50000 [02:25<4:47:53,  2.86it/s]
#
#
# Classifying train samples:   1%|          | 620/50000 [02:25<5:12:14,  2.64it/s]
#
#
# Classifying train samples:   1%|          | 621/50000 [02:26<5:31:27,  2.48it/s]
#
#
# Classifying train samples:   1%|          | 622/50000 [02:26<5:38:26,  2.43it/s]
#
#
# Classifying train samples:   1%|          | 623/50000 [02:26<5:41:21,  2.41it/s]
#
#
# Classifying train samples:   1%|          | 624/50000 [02:27<5:15:09,  2.61it/s]
#
#
# Classifying train samples:   1%|▏         | 625/50000 [02:27<4:31:07,  3.04it/s]
#
#
# Classifying train samples:   1%|▏         | 626/50000 [02:27<4:03:33,  3.38it/s]
#
#
# Classifying train samples:   1%|▏         | 627/50000 [02:27<3:40:52,  3.73it/s]
#
#
# Classifying train samples:   1%|▏         | 628/50000 [02:28<3:25:53,  4.00it/s]
#
#
# Classifying train samples:   1%|▏         | 629/50000 [02:28<3:16:44,  4.18it/s]
#
#
# Classifying train samples:   1%|▏         | 630/50000 [02:28<3:10:38,  4.32it/s]
#
#
# Classifying train samples:   1%|▏         | 631/50000 [02:28<3:01:48,  4.53it/s]
#
#
# Classifying train samples:   1%|▏         | 632/50000 [02:28<2:57:40,  4.63it/s]
#
#
# Classifying train samples:   1%|▏         | 633/50000 [02:29<2:54:17,  4.72it/s]
#
#
# Classifying train samples:   1%|▏         | 634/50000 [02:29<2:51:53,  4.79it/s]
#
#
# Classifying train samples:   1%|▏         | 635/50000 [02:29<2:54:08,  4.72it/s]
#
#
# Classifying train samples:   1%|▏         | 636/50000 [02:29<2:52:39,  4.76it/s]
#
#
# Classifying train samples:   1%|▏         | 637/50000 [02:29<2:50:02,  4.84it/s]
#
#
# Classifying train samples:   1%|▏         | 638/50000 [02:30<2:49:27,  4.85it/s]
#
#
# Classifying train samples:   1%|▏         | 639/50000 [02:30<2:52:53,  4.76it/s]
#
#
# Classifying train samples:   1%|▏         | 640/50000 [02:30<2:54:32,  4.71it/s]
#
#
# Classifying train samples:   1%|▏         | 641/50000 [02:30<2:50:55,  4.81it/s]
#
#
# Classifying train samples:   1%|▏         | 642/50000 [02:30<2:47:16,  4.92it/s]
#
#
# Classifying train samples:   1%|▏         | 643/50000 [02:31<2:48:11,  4.89it/s]
#
#
# Classifying train samples:   1%|▏         | 644/50000 [02:31<2:48:23,  4.89it/s]
#
#
# Classifying train samples:   1%|▏         | 645/50000 [02:31<2:52:40,  4.76it/s]
#
#
# Classifying train samples:   1%|▏         | 646/50000 [02:31<2:50:10,  4.83it/s]
#
#
# Classifying train samples:   1%|▏         | 647/50000 [02:31<2:47:59,  4.90it/s]
#
#
# Classifying train samples:   1%|▏         | 648/50000 [02:32<2:44:17,  5.01it/s]
#
#
# Classifying train samples:   1%|▏         | 649/50000 [02:32<2:47:24,  4.91it/s]
#
#
# Classifying train samples:   1%|▏         | 650/50000 [02:32<2:50:06,  4.83it/s]
#
#
# Classifying train samples:   1%|▏         | 651/50000 [02:32<2:50:50,  4.81it/s]
#
#
# Classifying train samples:   1%|▏         | 652/50000 [02:33<2:50:39,  4.82it/s]
#
#
# Classifying train samples:   1%|▏         | 653/50000 [02:33<2:50:31,  4.82it/s]
#
#
# Classifying train samples:   1%|▏         | 654/50000 [02:33<2:53:07,  4.75it/s]
#
#
# Classifying train samples:   1%|▏         | 655/50000 [02:33<2:55:09,  4.70it/s]
#
#
# Classifying train samples:   1%|▏         | 656/50000 [02:33<2:52:18,  4.77it/s]
#
#
# Classifying train samples:   1%|▏         | 657/50000 [02:34<2:48:15,  4.89it/s]
#
#
# Classifying train samples:   1%|▏         | 658/50000 [02:34<2:46:27,  4.94it/s]
#
#
# Classifying train samples:   1%|▏         | 659/50000 [02:34<2:47:58,  4.90it/s]
#
#
# Classifying train samples:   1%|▏         | 660/50000 [02:34<2:55:17,  4.69it/s]
#
#
# Classifying train samples:   1%|▏         | 661/50000 [02:34<2:52:37,  4.76it/s]
#
#
# Classifying train samples:   1%|▏         | 662/50000 [02:35<2:53:23,  4.74it/s]
#
#
# Classifying train samples:   1%|▏         | 663/50000 [02:35<2:55:31,  4.68it/s]
#
#
# Classifying train samples:   1%|▏         | 664/50000 [02:35<2:53:39,  4.74it/s]
#
#
# Classifying train samples:   1%|▏         | 665/50000 [02:35<3:01:27,  4.53it/s]
#
#
# Classifying train samples:   1%|▏         | 666/50000 [02:35<2:58:52,  4.60it/s]
#
#
# Classifying train samples:   1%|▏         | 667/50000 [02:36<2:54:37,  4.71it/s]
#
#
# Classifying train samples:   1%|▏         | 668/50000 [02:36<2:50:45,  4.81it/s]
#
#
# Classifying train samples:   1%|▏         | 669/50000 [02:36<2:49:11,  4.86it/s]
#
#
# Classifying train samples:   1%|▏         | 670/50000 [02:36<2:54:33,  4.71it/s]
#
#
# Classifying train samples:   1%|▏         | 671/50000 [02:37<2:54:40,  4.71it/s]
#
#
# Classifying train samples:   1%|▏         | 672/50000 [02:37<3:28:00,  3.95it/s]
#
#
# Classifying train samples:   1%|▏         | 673/50000 [02:37<4:12:35,  3.25it/s]
#
#
# Classifying train samples:   1%|▏         | 674/50000 [02:38<4:50:58,  2.83it/s]
#
#
# Classifying train samples:   1%|▏         | 675/50000 [02:38<5:14:18,  2.62it/s]
#
#
# Classifying train samples:   1%|▏         | 676/50000 [02:39<5:31:32,  2.48it/s]
#
#
# Classifying train samples:   1%|▏         | 677/50000 [02:39<5:48:29,  2.36it/s]
#
#
# Classifying train samples:   1%|▏         | 678/50000 [02:40<5:47:07,  2.37it/s]
#
#
# Classifying train samples:   1%|▏         | 679/50000 [02:40<5:44:56,  2.38it/s]
#
#
# Classifying train samples:   1%|▏         | 680/50000 [02:40<5:00:03,  2.74it/s]
#
#
# Classifying train samples:   1%|▏         | 681/50000 [02:40<4:27:21,  3.07it/s]
#
#
# Classifying train samples:   1%|▏         | 682/50000 [02:41<3:56:40,  3.47it/s]
#
#
# Classifying train samples:   1%|▏         | 683/50000 [02:41<3:38:59,  3.75it/s]
#
#
# Classifying train samples:   1%|▏         | 684/50000 [02:41<3:22:07,  4.07it/s]
#
#
# Classifying train samples:   1%|▏         | 685/50000 [02:41<3:13:05,  4.26it/s]
#
#
# Classifying train samples:   1%|▏         | 686/50000 [02:41<3:09:16,  4.34it/s]
#
#
# Classifying train samples:   1%|▏         | 687/50000 [02:42<3:02:14,  4.51it/s]
#
#
# Classifying train samples:   1%|▏         | 688/50000 [02:42<2:57:57,  4.62it/s]
#
#
# Classifying train samples:   1%|▏         | 689/50000 [02:42<2:51:46,  4.78it/s]
#
#
# Classifying train samples:   1%|▏         | 690/50000 [02:42<2:45:04,  4.98it/s]
#
#
# Classifying train samples:   1%|▏         | 691/50000 [02:42<2:51:06,  4.80it/s]
#
#
# Classifying train samples:   1%|▏         | 692/50000 [02:43<2:51:47,  4.78it/s]
#
#
# Classifying train samples:   1%|▏         | 693/50000 [02:43<2:51:55,  4.78it/s]
#
#
# Classifying train samples:   1%|▏         | 694/50000 [02:43<2:48:52,  4.87it/s]
#
#
# Classifying train samples:   1%|▏         | 695/50000 [02:43<2:47:59,  4.89it/s]
#
#
# Classifying train samples:   1%|▏         | 696/50000 [02:44<2:54:51,  4.70it/s]
#
#
# Classifying train samples:   1%|▏         | 697/50000 [02:44<2:52:26,  4.77it/s]
#
#
# Classifying train samples:   1%|▏         | 698/50000 [02:44<2:52:32,  4.76it/s]
#
#
# Classifying train samples:   1%|▏         | 699/50000 [02:44<2:48:59,  4.86it/s]
#
#
# Classifying train samples:   1%|▏         | 700/50000 [02:44<2:46:32,  4.93it/s]
#
#
# Classifying train samples:   1%|▏         | 701/50000 [02:45<2:47:36,  4.90it/s]
#
#
# Classifying train samples:   1%|▏         | 702/50000 [02:45<2:46:46,  4.93it/s]
#
#
# Classifying train samples:   1%|▏         | 703/50000 [02:45<2:55:18,  4.69it/s]
#
#
# Classifying train samples:   1%|▏         | 704/50000 [02:45<2:50:27,  4.82it/s]
#
#
# Classifying train samples:   1%|▏         | 705/50000 [02:45<2:52:43,  4.76it/s]
#
#
# Classifying train samples:   1%|▏         | 706/50000 [02:46<2:54:07,  4.72it/s]
#
#
# Classifying train samples:   1%|▏         | 707/50000 [02:46<2:52:49,  4.75it/s]
#
#
# Classifying train samples:   1%|▏         | 708/50000 [02:46<2:47:10,  4.91it/s]
#
#
# Classifying train samples:   1%|▏         | 709/50000 [02:46<2:46:51,  4.92it/s]
#
#
# Classifying train samples:   1%|▏         | 710/50000 [02:46<2:44:52,  4.98it/s]
#
#
# Classifying train samples:   1%|▏         | 711/50000 [02:47<2:51:22,  4.79it/s]
#
#
# Classifying train samples:   1%|▏         | 712/50000 [02:47<2:50:37,  4.81it/s]
#
#
# Classifying train samples:   1%|▏         | 713/50000 [02:47<2:47:02,  4.92it/s]
#
#
# Classifying train samples:   1%|▏         | 714/50000 [02:47<2:44:16,  5.00it/s]
#
#
# Classifying train samples:   1%|▏         | 715/50000 [02:47<2:43:38,  5.02it/s]
#
#
# Classifying train samples:   1%|▏         | 716/50000 [02:48<2:51:51,  4.78it/s]
#
#
# Classifying train samples:   1%|▏         | 717/50000 [02:48<2:49:14,  4.85it/s]
#
#
# Classifying train samples:   1%|▏         | 718/50000 [02:48<2:53:45,  4.73it/s]
#
#
# Classifying train samples:   1%|▏         | 719/50000 [02:48<3:00:32,  4.55it/s]
#
#
# Classifying train samples:   1%|▏         | 720/50000 [02:49<3:15:18,  4.21it/s]
#
#
# Classifying train samples:   1%|▏         | 721/50000 [02:49<3:09:36,  4.33it/s]
#
#
# Classifying train samples:   1%|▏         | 722/50000 [02:49<3:03:20,  4.48it/s]
#
#
# Classifying train samples:   1%|▏         | 723/50000 [02:49<3:01:03,  4.54it/s]
#
#
# Classifying train samples:   1%|▏         | 724/50000 [02:49<2:57:34,  4.62it/s]
#
#
# Classifying train samples:   1%|▏         | 725/50000 [02:50<3:00:46,  4.54it/s]
#
#
# Classifying train samples:   1%|▏         | 726/50000 [02:50<2:54:21,  4.71it/s]
#
#
# Classifying train samples:   1%|▏         | 727/50000 [02:50<2:54:35,  4.70it/s]
#
#
# Classifying train samples:   1%|▏         | 728/50000 [02:50<3:46:05,  3.63it/s]
#
#
# Classifying train samples:   1%|▏         | 729/50000 [02:51<4:29:36,  3.05it/s]
#
#
# Classifying train samples:   1%|▏         | 730/50000 [02:51<4:59:06,  2.75it/s]
#
#
# Classifying train samples:   1%|▏         | 731/50000 [02:52<5:08:35,  2.66it/s]
#
#
# Classifying train samples:   1%|▏         | 732/50000 [02:52<5:21:55,  2.55it/s]
#
#
# Classifying train samples:   1%|▏         | 733/50000 [02:53<5:39:30,  2.42it/s]
#
#
# Classifying train samples:   1%|▏         | 734/50000 [02:53<5:35:08,  2.45it/s]
#
#
# Classifying train samples:   1%|▏         | 735/50000 [02:54<5:40:20,  2.41it/s]
#
#
# Classifying train samples:   1%|▏         | 736/50000 [02:54<5:20:07,  2.56it/s]
#
#
# Classifying train samples:   1%|▏         | 737/50000 [02:54<4:42:30,  2.91it/s]
#
#
# Classifying train samples:   1%|▏         | 738/50000 [02:54<4:11:25,  3.27it/s]
#
#
# Classifying train samples:   1%|▏         | 739/50000 [02:55<3:47:59,  3.60it/s]
#
#
# Classifying train samples:   1%|▏         | 740/50000 [02:55<3:27:03,  3.96it/s]
#
#
# Classifying train samples:   1%|▏         | 741/50000 [02:55<3:21:16,  4.08it/s]
#
#
# Classifying train samples:   1%|▏         | 742/50000 [02:55<3:12:54,  4.26it/s]
#
#
# Classifying train samples:   1%|▏         | 743/50000 [02:55<3:06:44,  4.40it/s]
#
#
# Classifying train samples:   1%|▏         | 744/50000 [02:56<3:02:55,  4.49it/s]
#
#
# Classifying train samples:   1%|▏         | 745/50000 [02:56<2:57:59,  4.61it/s]
#
#
# Classifying train samples:   1%|▏         | 746/50000 [02:56<2:57:37,  4.62it/s]
#
#
# Classifying train samples:   1%|▏         | 747/50000 [02:56<2:56:40,  4.65it/s]
#
#
# Classifying train samples:   1%|▏         | 748/50000 [02:56<2:56:05,  4.66it/s]
#
#
# Classifying train samples:   1%|▏         | 749/50000 [02:57<2:54:09,  4.71it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7566f91bf68f> in <cell line: 65>()
#      63     return min(distances, key=distances.get)
#      64
# ---> 65 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      66 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      67
#
# <ipython-input-6-7566f91bf68f> in <listcomp>(.0)
#      63     return min(distances, key=distances.get)
#      64
# ---> 65 train_pred = np.array([classify_sample(x) for x in tqdm(train_features, desc="Classifying train samples")])
#      66 test_pred = np.array([classify_sample(x) for x in tqdm(test_features, desc="Classifying test samples")])
#      67
#
# <ipython-input-6-7566f91bf68f> in classify_sample(x)
#      60     distances = {}
#      61     for c in classes:
# ---> 62         distances[c] = mahalanobis_distance(x, class_means[c], class_cov_matrices[c])
#      63     return min(distances, key=distances.get)
#      64
#
# <ipython-input-6-7566f91bf68f> in mahalanobis_distance(x, mean, cov_matrix)
#      55
#      56 def mahalanobis_distance(x, mean, cov_matrix):
# ---> 57     return distance.mahalanobis(x, mean, np.linalg.inv(cov_matrix))
#      58
#      59 def classify_sample(x):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     550     signature = 'D->D' if isComplexType(t) else 'd->d'
#     551     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553     return wrap(ainv.astype(result_t, copy=False))
#     554
#
# KeyboardInterrupt:

# %% [markdown]
# 下面这个输入维度是64维

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from scipy.spatial.distance import mahalanobis
from tqdm import tqdm
import timm

# 设置GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 加载数据
transform = transforms.Compose([transforms.ToTensor()])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, shuffle=False)

# 使用timm库加载ResNet-18模型，并获取layer1输出
model = timm.create_model('resnet18', pretrained=True).to(device)
feature_extractor = torch.nn.Sequential(*list(model.children())[:-4]).to(device)  # 选择到layer1的输出

feature_extractor.eval()

# 特征提取函数
def extract_features(loader, model):
    features = []
    labels = []
    with torch.no_grad():
        for data in tqdm(loader, desc="Extracting features"):
            inputs, label = data
            inputs = inputs.to(device)
            feature = model(inputs) # 获取模型的特征
            feature = torch.nn.functional.adaptive_avg_pool2d(feature, (1, 1))
            feature = feature.reshape(feature.size(0), -1)
            features.append(feature.cpu())
            labels.append(label)
    features = torch.cat(features, 0)
    labels = torch.cat(labels, 0)
    return features, labels

train_features, train_labels = extract_features(trainloader, feature_extractor)
test_features, test_labels = extract_features(testloader, feature_extractor)

# 计算每个类别的均值和协方差矩阵的逆
class_means = {}
class_inv_cov_matrices = {}
for c in range(10):
    data_c = train_features[train_labels == c]
    class_means[c] = torch.mean(data_c, dim=0)
    cov_matrix = torch.tensor(np.cov(data_c, rowvar=False))
    class_inv_cov_matrices[c] = torch.linalg.inv(cov_matrix)

# 使用最小Mahalanobis距离分类器进行分类
def classify(features, means, inv_cov_matrices):
    pred_labels = []
    for feature in tqdm(features, desc="Classifying"):
        distances = []
        for c in range(10):
            m_distance = mahalanobis(feature, means[c], inv_cov_matrices[c])
            distances.append(m_distance)
        pred_labels.append(distances.index(min(distances)))
    return torch.tensor(pred_labels)

train_pred = classify(train_features, class_means, class_inv_cov_matrices)
test_pred = classify(test_features, class_means, class_inv_cov_matrices)

train_acc = (train_pred == train_labels).float().mean().item()
test_acc = (test_pred == test_labels).float().mean().item()

print(f"Training Accuracy: {train_acc * 100:.2f}%")
print(f"Testing Accuracy: {test_acc * 100:.2f}%")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# Extracting features:   0%|          | 0/98 [00:00<?, ?it/s]
#
#
#
# Extracting features:   2%|▏         | 2/98 [00:00<00:07, 13.01it/s]
#
#
#
# Extracting features:   4%|▍         | 4/98 [00:00<00:07, 13.05it/s]
#
#
#
# Extracting features:   6%|▌         | 6/98 [00:00<00:06, 13.19it/s]
#
#
#
# Extracting features:   8%|▊         | 8/98 [00:00<00:07, 12.68it/s]
#
#
#
# Extracting features:  10%|█         | 10/98 [00:00<00:06, 13.00it/s]
#
#
#
# Extracting features:  12%|█▏        | 12/98 [00:00<00:06, 12.99it/s]
#
#
#
# Extracting features:  14%|█▍        | 14/98 [00:01<00:06, 13.06it/s]
#
#
#
# Extracting features:  16%|█▋        | 16/98 [00:01<00:06, 12.90it/s]
#
#
#
# Extracting features:  18%|█▊        | 18/98 [00:01<00:06, 12.81it/s]
#
#
#
# Extracting features:  20%|██        | 20/98 [00:01<00:06, 12.61it/s]
#
#
#
# Extracting features:  22%|██▏       | 22/98 [00:01<00:05, 12.77it/s]
#
#
#
# Extracting features:  24%|██▍       | 24/98 [00:01<00:05, 12.96it/s]
#
#
#
# Extracting features:  27%|██▋       | 26/98 [00:02<00:05, 12.96it/s]
#
#
#
# Extracting features:  29%|██▊       | 28/98 [00:02<00:05, 12.99it/s]
#
#
#
# Extracting features:  31%|███       | 30/98 [00:02<00:05, 13.06it/s]
#
#
#
# Extracting features:  33%|███▎      | 32/98 [00:02<00:05, 13.01it/s]
#
#
#
# Extracting features:  35%|███▍      | 34/98 [00:02<00:05, 12.55it/s]
#
#
#
# Extracting features:  37%|███▋      | 36/98 [00:02<00:05, 11.06it/s]
#
#
#
# Extracting features:  39%|███▉      | 38/98 [00:03<00:05, 10.53it/s]
#
#
#
# Extracting features:  41%|████      | 40/98 [00:03<00:05, 10.27it/s]
#
#
#
# Extracting features:  43%|████▎     | 42/98 [00:03<00:05, 10.05it/s]
#
#
#
# Extracting features:  45%|████▍     | 44/98 [00:03<00:05,  9.56it/s]
#
#
#
# Extracting features:  46%|████▌     | 45/98 [00:03<00:05,  9.53it/s]
#
#
#
# Extracting features:  47%|████▋     | 46/98 [00:03<00:05,  9.46it/s]
#
#
#
# Extracting features:  48%|████▊     | 47/98 [00:04<00:05,  9.42it/s]
#
#
#
# Extracting features:  49%|████▉     | 48/98 [00:04<00:05,  9.29it/s]
#
#
#
# Extracting features:  50%|█████     | 49/98 [00:04<00:05,  9.26it/s]
#
#
#
# Extracting features:  51%|█████     | 50/98 [00:04<00:05,  9.22it/s]
#
#
#
# Extracting features:  52%|█████▏    | 51/98 [00:04<00:05,  9.02it/s]
#
#
#
# Extracting features:  53%|█████▎    | 52/98 [00:04<00:05,  8.85it/s]
#
#
#
# Classifying train samples:   0%|          | 0/50000 [35:43<?, ?it/s]
# Classifying train samples:   0%|          | 15/50000 [28:19<1573:18:31, 113.31s/it]
# Classifying train samples:   0%|          | 112/50000 [16:31<122:37:36,  8.85s/it]
#
#
#
#
# Extracting features:  55%|█████▌    | 54/98 [00:05<00:07,  5.84it/s]
#
#
#
# Extracting features:  56%|█████▌    | 55/98 [00:05<00:06,  6.26it/s]
#
#
#
# Extracting features:  58%|█████▊    | 57/98 [00:05<00:04,  8.24it/s]
#
#
#
# Extracting features:  60%|██████    | 59/98 [00:05<00:04,  9.52it/s]
#
#
#
# Extracting features:  62%|██████▏   | 61/98 [00:05<00:03, 10.53it/s]
#
#
#
# Extracting features:  64%|██████▍   | 63/98 [00:05<00:03, 10.80it/s]
#
#
#
# Extracting features:  66%|██████▋   | 65/98 [00:05<00:02, 11.46it/s]
#
#
#
# Extracting features:  68%|██████▊   | 67/98 [00:06<00:02, 11.62it/s]
#
#
#
# Extracting features:  70%|███████   | 69/98 [00:06<00:02, 12.05it/s]
#
#
#
# Extracting features:  72%|███████▏  | 71/98 [00:06<00:02, 12.23it/s]
#
#
#
# Extracting features:  74%|███████▍  | 73/98 [00:06<00:01, 12.50it/s]
#
#
#
# Extracting features:  77%|███████▋  | 75/98 [00:06<00:01, 12.64it/s]
#
#
#
# Extracting features:  79%|███████▊  | 77/98 [00:06<00:01, 12.55it/s]
#
#
#
# Extracting features:  81%|████████  | 79/98 [00:07<00:01, 12.75it/s]
#
#
#
# Extracting features:  83%|████████▎ | 81/98 [00:07<00:01, 12.44it/s]
#
#
#
# Extracting features:  85%|████████▍ | 83/98 [00:07<00:01, 12.65it/s]
#
#
#
# Extracting features:  87%|████████▋ | 85/98 [00:07<00:01, 12.66it/s]
#
#
#
# Extracting features:  89%|████████▉ | 87/98 [00:07<00:00, 12.77it/s]
#
#
#
# Extracting features:  91%|█████████ | 89/98 [00:07<00:00, 12.59it/s]
#
#
#
# Extracting features:  93%|█████████▎| 91/98 [00:08<00:00, 12.70it/s]
#
#
#
# Extracting features:  95%|█████████▍| 93/98 [00:08<00:00, 12.75it/s]
#
#
#
# Extracting features:  97%|█████████▋| 95/98 [00:08<00:00, 12.83it/s]
#
#
#
# Extracting features: 100%|██████████| 98/98 [00:08<00:00, 11.46it/s]
# Extracting features: 100%|██████████| 20/20 [00:01<00:00, 13.68it/s]
# Classifying: 100%|██████████| 50000/50000 [00:25<00:00, 1930.73it/s]
# Classifying: 100%|██████████| 10000/10000 [00:04<00:00, 2288.05it/s]
# Training Accuracy: 69.21%
# Testing Accuracy: 62.20%

# %% [markdown]
# 下面这个输出维度是256维

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from scipy.spatial.distance import mahalanobis
from tqdm import tqdm
import timm

# 设置GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 加载数据
transform = transforms.Compose([transforms.ToTensor()])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, shuffle=False)

# 使用timm库加载ResNet-50模型，并获取layer1输出
model = timm.create_model('resnet50', pretrained=True).to(device)
model.eval()

# 特征提取函数
def extract_features(loader, model):
    features = []
    labels = []
    with torch.no_grad():
        for data in tqdm(loader, desc="Extracting features"):
            inputs, label = data
            inputs = inputs.to(device)
            feature = model.forward_features(inputs)  # 获取模型的特征
            feature = torch.nn.functional.adaptive_avg_pool2d(feature, (1, 1))
            feature = feature.reshape(feature.size(0), -1)
            features.append(feature.cpu())
            labels.append(label)
    features = torch.cat(features, 0)
    labels = torch.cat(labels, 0)
    return features, labels

train_features, train_labels = extract_features(trainloader, model)
test_features, test_labels = extract_features(testloader, model)

# 计算每个类别的均值和协方差矩阵的逆
class_means = {}
class_inv_cov_matrices = {}
identity = torch.eye(train_features.size(1)).double() # 创建单位矩阵
regularization_term = 1e-6

for c in range(10):
    data_c = train_features[train_labels == c]
    class_means[c] = torch.mean(data_c, dim=0)
    cov_matrix = torch.tensor(np.cov(data_c, rowvar=False)) + regularization_term * identity
    class_inv_cov_matrices[c] = torch.linalg.inv(cov_matrix)

# 使用最小Mahalanobis距离分类器进行分类
def classify(features, means, inv_cov_matrices):
    pred_labels = []
    for feature in tqdm(features, desc="Classifying"):
        distances = []
        for c in range(10):
            m_distance = mahalanobis(feature, means[c], inv_cov_matrices[c])
            distances.append(m_distance)
        pred_labels.append(distances.index(min(distances)))
    return torch.tensor(pred_labels)

train_pred = classify(train_features, class_means, class_inv_cov_matrices)
test_pred = classify(test_features, class_means, class_inv_cov_matrices)

train_acc = (train_pred == train_labels).float().mean().item()
test_acc = (test_pred == test_labels).float().mean().item()

print(f"Training Accuracy: {train_acc * 100:.2f}%")
print(f"Testing Accuracy: {test_acc * 100:.2f}%")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Classifying train samples:   1%|▏         | 749/50000 [13:42<15:01:18,  1.10s/it]
# Extracting features: 100%|██████████| 98/98 [00:12<00:00,  7.99it/s]
# Extracting features: 100%|██████████| 20/20 [00:02<00:00,  8.78it/s]
# Classifying:   4%|▍         | 2197/50000 [01:03<22:55, 34.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a7cb93620f21> in <cell line: 67>()
#      65     return torch.tensor(pred_labels)
#      66
# ---> 67 train_pred = classify(train_features, class_means, class_inv_cov_matrices)
#      68 test_pred = classify(test_features, class_means, class_inv_cov_matrices)
#      69
#
# <ipython-input-9-a7cb93620f21> in classify(features, means, inv_cov_matrices)
#      60         distances = []
#      61         for c in range(10):
# ---> 62             m_distance = mahalanobis(feature, means[c], inv_cov_matrices[c])
#      63             distances.append(m_distance)
#      64         pred_labels.append(distances.index(min(distances)))
#
# /usr/local/lib/python3.10/dist-packages/scipy/spatial/distance.py in mahalanobis(u, v, VI)
#    1020     VI = np.atleast_2d(VI)
#    1021     delta = u - v
# -> 1022     m = np.dot(np.dot(delta, VI), delta)
#    1023     return np.sqrt(m)
#    1024
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# final

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from scipy.spatial.distance import mahalanobis
from tqdm import tqdm
import timm
import numpy as np

# 设置GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 加载数据
transform = transforms.Compose([transforms.ToTensor()])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, shuffle=False)
train_labels = np.concatenate([data[1].numpy() for data in trainloader], 0)
test_labels = np.concatenate([data[1].numpy() for data in testloader], 0)

# 特征提取函数
def extract_pca_features(trainloader, testloader):
    train_data = np.concatenate([data[0].numpy().reshape(data[0].shape[0], -1) for data in tqdm(trainloader, desc="PCA - Processing Train Data")], 0)
    test_data = np.concatenate([data[0].numpy().reshape(data[0].shape[0], -1) for data in tqdm(testloader, desc="PCA - Processing Test Data")], 0)
    pca = PCA(0.9)
    train_features = pca.fit_transform(train_data)
    test_features = pca.transform(test_data)
    return train_features, test_features

def extract_lda_features(trainloader, testloader):
    train_data = np.concatenate([data[0].numpy().reshape(data[0].shape[0], -1) for data in tqdm(trainloader, desc="LDA - Processing Train Data")], 0)
    test_data = np.concatenate([data[0].numpy().reshape(data[0].shape[0], -1) for data in tqdm(testloader, desc="LDA - Processing Test Data")], 0)
    lda = LDA()
    train_features = lda.fit_transform(train_data, train_labels)
    test_features = lda.transform(test_data)
    return train_features, test_features

def extract_resnet_features(trainloader, testloader):
    model = timm.create_model('resnet18', pretrained=True, num_classes=0)
    model = model.to(device)
    model.eval()

    def get_features(loader, desc="ResNet - Processing Data"):
        features = []
        for data in tqdm(loader, desc=desc):
            inputs, _ = data
            inputs = inputs.to(device)
            feature = model.forward_features(inputs)
            feature = torch.nn.functional.adaptive_avg_pool2d(feature, (1, 1))
            feature = feature.reshape(feature.size(0), -1)
            features.append(feature.cpu().detach().numpy())
        return np.concatenate(features, 0)

    train_features = get_features(trainloader, desc="ResNet - Processing Train Data")
    test_features = get_features(testloader, desc="ResNet - Processing Test Data")
    return train_features, test_features

# 定义Mahalanobis分类器
def classify_with_mahalanobis(train_features, test_features, train_labels):
    means = {}
    inv_cov_matrices = {}
    regularization = np.eye(train_features.shape[1]) * 1e-6
    for c in tqdm(range(10), desc="Computing Class Means and Inverse Covariance"):
        data_c = train_features[train_labels == c]
        means[c] = np.mean(data_c, axis=0)
        cov_matrix = np.cov(data_c, rowvar=False) + regularization
        inv_cov_matrices[c] = np.linalg.inv(cov_matrix)

    predictions = []
    for feature in tqdm(test_features, desc="Classifying"):
        distances = [mahalanobis(feature, means[c], inv_cov_matrices[c]) for c in range(10)]
        predictions.append(np.argmin(distances))

    return np.array(predictions)

# 主程序
def main():
    methods = ["PCA", "LDA", "RESNET-18"]
    train_features_methods = [extract_pca_features, extract_lda_features, extract_resnet_features]

    for method, feature_func in zip(methods, train_features_methods):
        print(f"\nProcessing {method} features...")
        train_features, test_features = feature_func(trainloader, testloader)
        test_pred = classify_with_mahalanobis(train_features, test_features, train_labels)
        acc = np.mean(test_pred == test_labels)
        print(f"\n{method} Test Accuracy: {acc * 100:.2f}%")
        print("-------------------------")

if __name__ == "__main__":
    main()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Processing PCA features...
# PCA - Processing Train Data: 100%|██████████| 98/98 [00:06<00:00, 15.15it/s]
# PCA - Processing Test Data: 100%|██████████| 20/20 [00:01<00:00, 15.11it/s]
# Computing Class Means and Inverse Covariance: 100%|██████████| 10/10 [00:00<00:00, 127.76it/s]
# Classifying: 100%|██████████| 10000/10000 [00:02<00:00, 4823.01it/s]
# PCA Test Accuracy: 9.31%
# -------------------------
#
# Processing LDA features...
# LDA - Processing Train Data: 100%|██████████| 98/98 [00:07<00:00, 13.22it/s]
# LDA - Processing Test Data: 100%|██████████| 20/20 [00:01<00:00, 14.49it/s]
# Computing Class Means and Inverse Covariance: 100%|██████████| 10/10 [00:00<00:00, 529.93it/s]
# Classifying: 100%|██████████| 10000/10000 [00:00<00:00, 13817.54it/s]
# LDA Test Accuracy: 9.96%
# -------------------------
#
# Processing RESNET-18 features...
# ResNet - Processing Train Data: 100%|██████████| 98/98 [00:11<00:00,  8.41it/s]
# ResNet - Processing Test Data: 100%|██████████| 20/20 [00:02<00:00,  8.37it/s]
# Computing Class Means and Inverse Covariance: 100%|██████████| 10/10 [00:00<00:00, 15.43it/s]
# Classifying: 100%|██████████| 10000/10000 [00:12<00:00, 773.03it/s]
# RESNET-18 Test Accuracy: 9.20%
# -------------------------

# %% [markdown]
# 输出64维

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from scipy.spatial.distance import mahalanobis
from tqdm import tqdm
import timm

# 设置GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 加载数据
transform = transforms.Compose([transforms.ToTensor()])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, shuffle=False)

# 使用timm库加载ResNet-18模型，并获取layer1输出
model = timm.create_model('resnet18', pretrained=True).to(device)
feature_extractor = torch.nn.Sequential(*list(model.children())[:-4]).to(device)  # 选择到layer1的输出

feature_extractor.eval()

# 特征提取函数
def extract_features(loader, model):
    features = []
    labels = []
    with torch.no_grad():
        for data in tqdm(loader, desc="Extracting features"):
            inputs, label = data
            inputs = inputs.to(device)
            feature = model(inputs) # 获取模型的特征
            feature = torch.nn.functional.adaptive_avg_pool2d(feature, (1, 1))
            feature = feature.reshape(feature.size(0), -1)
            features.append(feature.cpu())
            labels.append(label)
    features = torch.cat(features, 0)
    labels = torch.cat(labels, 0)
    return features, labels

train_features, train_labels = extract_features(trainloader, feature_extractor)
test_features, test_labels = extract_features(testloader, feature_extractor)

# 计算每个类别的均值和协方差矩阵的逆
class_means = {}
class_inv_cov_matrices = {}
for c in range(10):
    data_c = train_features[train_labels == c]
    class_means[c] = torch.mean(data_c, dim=0)
    cov_matrix = torch.tensor(np.cov(data_c, rowvar=False))
    class_inv_cov_matrices[c] = torch.linalg.inv(cov_matrix)

# 使用最小Mahalanobis距离分类器进行分类
def classify(features, means, inv_cov_matrices):
    pred_labels = []
    for feature in tqdm(features, desc="Classifying"):
        distances = []
        for c in range(10):
            m_distance = mahalanobis(feature, means[c], inv_cov_matrices[c])
            distances.append(m_distance)
        pred_labels.append(distances.index(min(distances)))
    return torch.tensor(pred_labels)

train_pred = classify(train_features, class_means, class_inv_cov_matrices)
test_pred = classify(test_features, class_means, class_inv_cov_matrices)

train_acc = (train_pred == train_labels).float().mean().item()
test_acc = (test_pred == test_labels).float().mean().item()

print(f"Training Accuracy: {train_acc * 100:.2f}%")
print(f"Testing Accuracy: {test_acc * 100:.2f}%")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Extracting features: 100%|██████████| 98/98 [00:08<00:00, 11.83it/s]
# Extracting features: 100%|██████████| 20/20 [00:01<00:00, 10.52it/s]
# Classifying: 100%|██████████| 50000/50000 [00:24<00:00, 2020.69it/s]
# Classifying: 100%|██████████| 10000/10000 [00:05<00:00, 1926.80it/s]
# Training Accuracy: 69.22%
# Testing Accuracy: 62.20%

# %% [markdown]
# 输出256维

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from scipy.spatial.distance import mahalanobis
from tqdm import tqdm
import timm

# 设置GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 加载数据
transform = transforms.Compose([transforms.ToTensor()])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, shuffle=False)

# 使用timm库加载ResNet-50模型，并获取layer1输出
model = timm.create_model('resnet50', pretrained=True).to(device)
model.eval()

# 特征提取函数
def extract_features(loader, model):
    features = []
    labels = []
    with torch.no_grad():
        for data in tqdm(loader, desc="Extracting features"):
            inputs, label = data
            inputs = inputs.to(device)
            feature = model.forward_features(inputs)  # 获取模型的特征
            feature = torch.nn.functional.adaptive_avg_pool2d(feature, (1, 1))
            feature = feature.reshape(feature.size(0), -1)
            features.append(feature.cpu())
            labels.append(label)
    features = torch.cat(features, 0)
    labels = torch.cat(labels, 0)
    return features, labels

train_features, train_labels = extract_features(trainloader, model)
test_features, test_labels = extract_features(testloader, model)

# 计算每个类别的均值和协方差矩阵的逆
class_means = {}
class_inv_cov_matrices = {}
identity = torch.eye(train_features.size(1)).double() # 创建单位矩阵
regularization_term = 1e-6

for c in range(10):
    data_c = train_features[train_labels == c]
    class_means[c] = torch.mean(data_c, dim=0)
    cov_matrix = torch.tensor(np.cov(data_c, rowvar=False)) + regularization_term * identity
    class_inv_cov_matrices[c] = torch.linalg.inv(cov_matrix)

# 使用最小Mahalanobis距离分类器进行分类
def classify(features, means, inv_cov_matrices):
    pred_labels = []
    for feature in tqdm(features, desc="Classifying"):
        distances = []
        for c in range(10):
            m_distance = mahalanobis(feature, means[c], inv_cov_matrices[c])
            distances.append(m_distance)
        pred_labels.append(distances.index(min(distances)))
    return torch.tensor(pred_labels)

train_pred = classify(train_features, class_means, class_inv_cov_matrices)
test_pred = classify(test_features, class_means, class_inv_cov_matrices)

train_acc = (train_pred == train_labels).float().mean().item()
test_acc = (test_pred == test_labels).float().mean().item()

print(f"Training Accuracy: {train_acc * 100:.2f}%")
print(f"Testing Accuracy: {test_acc * 100:.2f}%")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Extracting features:   0%|          | 0/98 [00:00<?, ?it/s]
# Extracting features:   1%|          | 1/98 [00:00<00:22,  4.26it/s]
# Extracting features:   2%|▏         | 2/98 [00:00<00:19,  4.93it/s]
# Extracting features:   3%|▎         | 3/98 [00:00<00:17,  5.56it/s]
# Extracting features:   4%|▍         | 4/98 [00:00<00:15,  6.09it/s]
# Extracting features:   5%|▌         | 5/98 [00:00<00:14,  6.50it/s]
# Extracting features:   6%|▌         | 6/98 [00:00<00:13,  6.73it/s]
# Extracting features:   7%|▋         | 7/98 [00:01<00:12,  7.05it/s]
# Extracting features:   8%|▊         | 8/98 [00:01<00:12,  7.35it/s]
# Extracting features:   9%|▉         | 9/98 [00:01<00:11,  7.49it/s]
# Extracting features:  10%|█         | 10/98 [00:01<00:11,  7.66it/s]
# Extracting features:  11%|█         | 11/98 [00:01<00:11,  7.63it/s]
# Extracting features:  12%|█▏        | 12/98 [00:01<00:11,  7.70it/s]
# Extracting features:  13%|█▎        | 13/98 [00:01<00:10,  7.76it/s]
# Extracting features:  14%|█▍        | 14/98 [00:02<00:11,  7.61it/s]
# Extracting features:  15%|█▌        | 15/98 [00:02<00:10,  7.68it/s]
# Extracting features:  16%|█▋        | 16/98 [00:02<00:10,  7.69it/s]
# Extracting features:  17%|█▋        | 17/98 [00:02<00:10,  7.51it/s]
# Extracting features:  18%|█▊        | 18/98 [00:02<00:10,  7.65it/s]
# Extracting features:  19%|█▉        | 19/98 [00:02<00:10,  7.67it/s]
# Extracting features:  20%|██        | 20/98 [00:02<00:10,  7.79it/s]
# Extracting features:  21%|██▏       | 21/98 [00:02<00:09,  7.88it/s]
# Extracting features:  22%|██▏       | 22/98 [00:03<00:09,  7.83it/s]
# Extracting features:  23%|██▎       | 23/98 [00:03<00:09,  7.90it/s]
# Extracting features:  24%|██▍       | 24/98 [00:03<00:09,  7.89it/s]
# Extracting features:  26%|██▌       | 25/98 [00:03<00:09,  7.72it/s]
# Extracting features:  27%|██▋       | 26/98 [00:03<00:09,  7.70it/s]
# Extracting features:  28%|██▊       | 27/98 [00:03<00:09,  7.74it/s]
# Extracting features:  29%|██▊       | 28/98 [00:03<00:08,  7.85it/s]
# Extracting features:  30%|██▉       | 29/98 [00:03<00:08,  7.72it/s]
# Extracting features:  31%|███       | 30/98 [00:04<00:08,  7.77it/s]
# Extracting features:  32%|███▏      | 31/98 [00:04<00:08,  7.78it/s]
# Extracting features:  33%|███▎      | 32/98 [00:04<00:08,  7.77it/s]
# Extracting features:  34%|███▎      | 33/98 [00:04<00:08,  7.56it/s]
# Extracting features:  35%|███▍      | 34/98 [00:04<00:08,  7.62it/s]
# Extracting features:  36%|███▌      | 35/98 [00:04<00:08,  7.75it/s]
# Extracting features:  37%|███▋      | 36/98 [00:04<00:08,  7.75it/s]
# Extracting features:  38%|███▊      | 37/98 [00:04<00:07,  7.77it/s]
# Extracting features:  39%|███▉      | 38/98 [00:05<00:07,  7.83it/s]
# Extracting features:  40%|███▉      | 39/98 [00:05<00:07,  7.86it/s]
# Extracting features:  41%|████      | 40/98 [00:05<00:07,  7.90it/s]
# Extracting features:  42%|████▏     | 41/98 [00:05<00:07,  7.77it/s]
# Extracting features:  43%|████▎     | 42/98 [00:05<00:07,  7.69it/s]
# Extracting features:  44%|████▍     | 43/98 [00:05<00:07,  7.77it/s]
# Extracting features:  45%|████▍     | 44/98 [00:05<00:06,  7.86it/s]
# Extracting features:  46%|████▌     | 45/98 [00:05<00:06,  7.87it/s]
# Extracting features:  47%|████▋     | 46/98 [00:06<00:06,  7.93it/s]
# Extracting features:  48%|████▊     | 47/98 [00:06<00:06,  7.74it/s]
# Extracting features:  49%|████▉     | 48/98 [00:06<00:06,  7.74it/s]
# Extracting features:  50%|█████     | 49/98 [00:06<00:06,  7.63it/s]
# Extracting features:  51%|█████     | 50/98 [00:06<00:06,  7.68it/s]
# Extracting features:  52%|█████▏    | 51/98 [00:06<00:06,  7.51it/s]
# Extracting features:  53%|█████▎    | 52/98 [00:06<00:06,  7.53it/s]
# Extracting features:  54%|█████▍    | 53/98 [00:07<00:05,  7.62it/s]
# Extracting features:  55%|█████▌    | 54/98 [00:07<00:05,  7.68it/s]
# Extracting features:  56%|█████▌    | 55/98 [00:07<00:05,  7.78it/s]
# Extracting features:  57%|█████▋    | 56/98 [00:07<00:05,  7.68it/s]
# Extracting features:  58%|█████▊    | 57/98 [00:07<00:05,  7.56it/s]
# Extracting features:  59%|█████▉    | 58/98 [00:07<00:05,  7.69it/s]
# Extracting features:  60%|██████    | 59/98 [00:07<00:05,  7.62it/s]
# Extracting features:  61%|██████    | 60/98 [00:07<00:04,  7.69it/s]
# Extracting features:  62%|██████▏   | 61/98 [00:08<00:04,  7.70it/s]
# Extracting features:  63%|██████▎   | 62/98 [00:08<00:04,  7.71it/s]
# Extracting features:  64%|██████▍   | 63/98 [00:08<00:04,  7.70it/s]
# Extracting features:  65%|██████▌   | 64/98 [00:08<00:04,  7.64it/s]
# Extracting features:  66%|██████▋   | 65/98 [00:08<00:04,  7.62it/s]
# Extracting features:  67%|██████▋   | 66/98 [00:08<00:04,  7.59it/s]
# Extracting features:  68%|██████▊   | 67/98 [00:08<00:04,  7.54it/s]
# Extracting features:  69%|██████▉   | 68/98 [00:09<00:03,  7.59it/s]
# Extracting features:  70%|███████   | 69/98 [00:09<00:03,  7.53it/s]
# Extracting features:  71%|███████▏  | 70/98 [00:09<00:03,  7.57it/s]
# Extracting features:  72%|███████▏  | 71/98 [00:09<00:03,  7.47it/s]
# Extracting features:  73%|███████▎  | 72/98 [00:09<00:03,  7.40it/s]
# Extracting features:  74%|███████▍  | 73/98 [00:09<00:03,  7.51it/s]
# Extracting features:  76%|███████▌  | 74/98 [00:09<00:03,  7.56it/s]
# Extracting features:  77%|███████▋  | 75/98 [00:09<00:03,  7.39it/s]
# Extracting features:  78%|███████▊  | 76/98 [00:10<00:03,  6.75it/s]
# Extracting features:  79%|███████▊  | 77/98 [00:10<00:03,  6.54it/s]
# Extracting features:  80%|███████▉  | 78/98 [00:10<00:03,  6.32it/s]
# Extracting features:  81%|████████  | 79/98 [00:10<00:03,  6.13it/s]
# Extracting features:  82%|████████▏ | 80/98 [00:10<00:02,  6.08it/s]
# Extracting features:  83%|████████▎ | 81/98 [00:10<00:02,  6.07it/s]
# Extracting features:  84%|████████▎ | 82/98 [00:11<00:02,  6.05it/s]
# Extracting features:  85%|████████▍ | 83/98 [00:11<00:02,  6.02it/s]
# Extracting features:  86%|████████▌ | 84/98 [00:11<00:02,  6.04it/s]
# Extracting features:  87%|████████▋ | 85/98 [00:11<00:02,  6.01it/s]
# Extracting features:  88%|████████▊ | 86/98 [00:11<00:01,  6.01it/s]
# Extracting features:  89%|████████▉ | 87/98 [00:11<00:01,  5.99it/s]
# Extracting features:  90%|████████▉ | 88/98 [00:12<00:01,  5.91it/s]
# Extracting features:  91%|█████████ | 89/98 [00:12<00:01,  5.88it/s]
# Extracting features:  92%|█████████▏| 90/98 [00:12<00:01,  5.64it/s]
# Extracting features:  93%|█████████▎| 91/98 [00:12<00:01,  5.41it/s]
# Extracting features:  94%|█████████▍| 92/98 [00:12<00:01,  5.85it/s]
# Extracting features:  95%|█████████▍| 93/98 [00:12<00:00,  6.24it/s]
# Extracting features:  96%|█████████▌| 94/98 [00:13<00:00,  6.56it/s]
# Extracting features:  97%|█████████▋| 95/98 [00:13<00:00,  6.86it/s]
# Extracting features:  98%|█████████▊| 96/98 [00:13<00:00,  7.08it/s]
# Extracting features: 100%|██████████| 98/98 [00:13<00:00,  7.20it/s]
#
# Extracting features:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting features:   5%|▌         | 1/20 [00:00<00:02,  8.17it/s]
# Extracting features:  10%|█         | 2/20 [00:00<00:02,  7.54it/s]
# Extracting features:  15%|█▌        | 3/20 [00:00<00:02,  7.65it/s]
# Classifying train samples:   0%|          | 0/50000 [18:02<?, ?it/s]
#
# Extracting features:  25%|██▌       | 5/20 [00:00<00:02,  5.27it/s]
# Extracting features:  30%|███       | 6/20 [00:00<00:02,  5.94it/s]
# Extracting features:  35%|███▌      | 7/20 [00:01<00:02,  6.42it/s]
# Extracting features:  40%|████      | 8/20 [00:01<00:01,  6.83it/s]
# Extracting features:  45%|████▌     | 9/20 [00:01<00:01,  7.23it/s]
# Extracting features:  50%|█████     | 10/20 [00:01<00:01,  7.22it/s]
# Extracting features:  55%|█████▌    | 11/20 [00:01<00:01,  7.38it/s]
# Extracting features:  60%|██████    | 12/20 [00:01<00:01,  7.52it/s]
# Extracting features:  65%|██████▌   | 13/20 [00:01<00:00,  7.65it/s]
# Extracting features:  70%|███████   | 14/20 [00:01<00:00,  7.75it/s]
# Extracting features:  75%|███████▌  | 15/20 [00:02<00:00,  7.73it/s]
# Extracting features:  80%|████████  | 16/20 [00:02<00:00,  7.73it/s]
# Extracting features:  85%|████████▌ | 17/20 [00:02<00:00,  7.76it/s]
# Extracting features:  90%|█████████ | 18/20 [00:02<00:00,  7.77it/s]
# Extracting features: 100%|██████████| 20/20 [00:02<00:00,  7.44it/s]
# Classifying: 100%|██████████| 50000/50000 [24:19<00:00, 34.25it/s]
# Classifying: 100%|██████████| 10000/10000 [04:51<00:00, 34.34it/s]
# Training Accuracy: 79.61%
# Testing Accuracy: 49.57%
